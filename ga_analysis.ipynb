# %%
# %matplotlib inline
import os
import igraph as ig
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# %% [markdown]
# ## Analysis of Genetic Algorithms for Community Detection in Complex Networks

# %%
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("ClusterResults.db")
df = pd.read_sql_query("SELECT * from ClusterResults", con)

# Verify that result of SQL query is stored in the dataframe
con.close()
df.head()
# Out:
#    algo            seed                                               file  \
# 0  gals  12785326941766  D:/alien-pineapple/benchmark_gen/gml_files/ben...
# 1  gals  12785326941766  D:/alien-pineapple/benchmark_gen/gml_files/ben...
# 2  gals  12785326941766  D:/alien-pineapple/benchmark_gen/gml_files/ben...
# 3  gals  12785326941766  D:/alien-pineapple/benchmark_gen/gml_files/ben...
# 4  gals  12785326941766  D:/alien-pineapple/benchmark_gen/gml_files/ben...
#
#                                       average_scores  \
# 0  0.22289794921875\n0.36231892903645835\n0.44061...
# 1  0.22473347981770833\n0.3542476399739583\n0.427...
# 2  0.228812255859375\n0.365767822265625\n0.446151...
# 3  0.22015625\n0.34891927083333335\n0.42802083333...
# 4  0.22197306315104168\n0.34857096354166667\n0.43...
#
#                                          best_scores final_score  \
# 0  0.512451171875\n0.5643310546875\n0.57702636718...  0.65234375
# 1  0.4285888671875\n0.5560302734375\n0.5732421875...  0.65234375
# 2  0.4886474609375\n0.50537109375\n0.60400390625\...  0.65234375
# 3  0.4190673828125\n0.551513671875\n0.59521484375...  0.65234375
# 4  0.4366455078125\n0.5635986328125\n0.6212158203...  0.65234375
#
#                     params_file  \
# 0  impl_GALS/default.properties
# 1  impl_GALS/default.properties
# 2  impl_GALS/default.properties
# 3  impl_GALS/default.properties
# 4  impl_GALS/default.properties
#
#                                           membership  nmi  rand   vi
# 0  1,2,3,4,2,3,3,4,2,1,2,4,2,1,3,2,4,2,3,2,4,1,3,...  0.0   0.0  0.0
# 1  1,2,3,4,2,3,3,4,2,1,2,4,2,1,3,2,4,2,3,2,4,1,3,...  0.0   0.0  0.0
# 2  1,2,3,4,2,3,3,4,2,1,2,4,2,1,3,2,4,2,3,2,4,1,3,...  0.0   0.0  0.0
# 3  1,2,3,4,2,3,3,4,2,1,2,4,2,1,3,2,4,2,3,2,4,1,3,...  0.0   0.0  0.0
# 4  1,2,3,4,2,3,3,4,2,1,2,4,2,1,3,2,4,2,3,2,4,1,3,...  0.0   0.0  0.0

# %%
df['membership'] = df['membership'].apply(lambda s: map(int, s.split(',')))
df['best_scores'] = df['best_scores'].apply(lambda s: map(float, s.split('\n')))
df['average_scores'] = df['average_scores'].apply(lambda s: map(float, s.split('\n')))

# %%
df['filename'] = df['file'].apply(lambda s: os.path.basename(s))

# %%
def getTrueComs(file):
    true_file = file + ".coms"
    if os.path.exists(true_file):
        data = pd.read_csv(true_file, sep='\t', header=None)
        return list(data[1].as_matrix())
    else:
        return []

# %%
df['true_membership'] = df['file'].apply(lambda s: getTrueComs(s))

# %% [markdown]
# ## Comparison Metrics
#
# @article{rand1971,
#   added-at = {2006-03-21T11:09:44.000+0100},
#   author = {Rand, W.M.},
#   biburl = {https://www.bibsonomy.org/bibtex/2fd52548cb4bcd8e83dd27e4b55eff1f3/hotho},
#   interhash = {1afaf0170bc705a9e49b625f67679ee2},
#   intrahash = {fd52548cb4bcd8e83dd27e4b55eff1f3},
#   journal = {Journal of the American Statistical Association },
#   keywords = {cluster clustering criteria evaluation index rand},
#   number = 336,
#   pages = {846-850},
#   timestamp = {2007-09-18T14:44:34.000+0200},
#   title = {Objective criteria for the evaluation of clustering methods},
#   volume = 66,
#   year = 1971
# }

# %%
df['nmi'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="nmi"), axis=1)

df['vi'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="vi"), axis=1)

df['rand'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="rand"), axis=1)

df['adjusted_rand'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="adjusted_rand"), axis=1)

df['split_join'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="split-join"), axis=1)

# %%
df.head()
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
def identifyConverge(vals):
    """find the earliest occurance of the maximum value in a list
    """
    best = vals[-1]
    if vals[0] == best:
        return 0
    for i in range(len(vals)):
        if vals[i] == best:
            return i

# %%
df['converge_gen'] = df['best_scores'].apply(identifyConverge)
df['gens'] = df['best_scores'].apply(len)

# %%
gals = df.loc[lambda dd: dd['algo'] == 'gals']
gacd = df.loc[lambda dd: dd['algo'] == 'gacd']
tbga = df.loc[lambda dd: dd['algo'] == 'tasgin']
ganet = df.loc[lambda dd: dd['algo'] == 'ganet']

# %%
def highlight_max(s):
    """
    highlight the maximum in a Series yellow.
    """
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
gals_valtable = gals.groupby(['filename','params_file'], sort=False)['nmi'].max().reset_index().pivot('filename', 'params_file', 'nmi').reset_index()
gals_valtable
# Out:
# params_file                    filename  default.properties  \
# 0                      girvan_mu1_0.gml                 NaN
# 1                      girvan_mu2_0.gml                 NaN
# 2                      girvan_mu3_0.gml                 NaN
# 3                      girvan_mu4_0.gml                 NaN
# 4                      girvan_mu5_0.gml                 NaN
# 5                      girvan_mu6_0.gml                 NaN
# 6                      girvan_mu7_0.gml                 NaN
# 7                      girvan_mu8_0.gml                 NaN
# 8            lfr_10000_mu3_s_size_0.gml            0.468401
# 9                  lfr_1000_mu1_b_0.gml                 NaN
# 10                 lfr_1000_mu1_s_0.gml                 NaN
# 11                 lfr_1000_mu2_b_0.gml                 NaN
# 12                 lfr_1000_mu2_s_0.gml                 NaN
# 13                 lfr_1000_mu3_b_0.gml                 NaN
# 14                 lfr_1000_mu3_s_0.gml                 NaN
# 15            lfr_1000_mu3_s_size_0.gml                 NaN
# 16                 lfr_1000_mu4_b_0.gml                 NaN
# 17                 lfr_1000_mu4_s_0.gml                 NaN
# 18                 lfr_1000_mu5_b_0.gml                 NaN
# 19                 lfr_1000_mu5_s_0.gml                 NaN
# 20                 lfr_1000_mu6_b_0.gml                 NaN
# 21                 lfr_1000_mu6_s_0.gml                 NaN
# 22            lfr_2000_mu3_s_size_0.gml                 NaN
# 23            lfr_3000_mu3_s_size_0.gml                 NaN
# 24            lfr_4000_mu3_s_size_0.gml                 NaN
# 25                 lfr_5000_mu1_b_0.gml                 NaN
# 26                 lfr_5000_mu1_s_0.gml                 NaN
# 27                 lfr_5000_mu2_b_0.gml                 NaN
# 28                 lfr_5000_mu2_s_0.gml                 NaN
# 29                 lfr_5000_mu3_b_0.gml                 NaN
# 30                 lfr_5000_mu3_s_0.gml                 NaN
# 31            lfr_5000_mu3_s_size_0.gml                 NaN
# 32                 lfr_5000_mu4_b_0.gml                 NaN
# 33                 lfr_5000_mu4_s_0.gml                 NaN
# 34                 lfr_5000_mu5_b_0.gml                 NaN
# 35                 lfr_5000_mu5_s_0.gml                 NaN
# 36                 lfr_5000_mu6_b_0.gml                 NaN
# 37                 lfr_5000_mu6_s_0.gml                 NaN
# 38            lfr_6000_mu3_s_size_0.gml                 NaN
# 39            lfr_7000_mu3_s_size_0.gml                 NaN
# 40            lfr_8000_mu3_s_size_0.gml                 NaN
# 41            lfr_9000_mu3_s_size_0.gml                 NaN
#
# params_file  impl_GALS/default.properties  impl_GALS/large.properties
# 0                                1.000000                    1.000000
# 1                                1.000000                    1.000000
# 2                                1.000000                    1.000000
# 3                                1.000000                    1.000000
# 4                                0.366633                    0.581218
# 5                                0.149342                    0.144851
# 6                                0.086256                    0.097474
# 7                                0.062592                    0.048741
# 8                                0.469977                    0.468929
# 9                                0.976939                    0.992912
# 10                               0.988292                    0.992151
# 11                               0.964500                    0.989690
# 12                               0.981764                    0.993266
# 13                               0.960092                    0.983679
# 14                               0.980050                    0.994664
# 15                               0.977441                    0.984828
# 16                               0.959031                    0.986170
# 17                               0.973896                    0.993647
# 18                               0.864985                    0.978771
# 19                               0.964818                    0.986407
# 20                               0.369299                    0.806230
# 21                               0.912507                    0.977727
# 22                               0.966191                    0.977963
# 23                               0.969099                    0.977913
# 24                               0.970147                    0.977898
# 25                               0.960461                    0.974669
# 26                               0.975171                    0.980693
# 27                               0.954861                    0.974181
# 28                               0.972843                    0.981627
# 29                               0.952757                    0.970606
# 30                               0.969559                    0.977898
# 31                               0.966719                    0.978337
# 32                               0.941434                    0.965874
# 33                               0.963733                    0.977166
# 34                               0.927722                    0.959194
# 35                               0.956633                    0.969681
# 36                               0.839154                    0.942071
# 37                               0.939235                    0.964493
# 38                               0.968863                    0.975221
# 39                               0.968321                    0.975289
# 40                               0.967976                    0.977625
# 41                               0.967298                    0.974910

# %%
with open('gals.tex','w') as tf:
    tf.write(gals_valtable.to_latex())

# %%
ganet_valtable = ganet.groupby(['filename','params_file'], sort=False)['nmi'].mean().reset_index().pivot('filename', 'params_file', 'nmi')
ganet_valtable
# Out:
# params_file                 impl_GANET/balanced_c_m.properties  \
# filename
# dolphins.gml                                               NaN
# football.gml                                               NaN
# girvan_mu1_0.gml                                           NaN
# girvan_mu2_0.gml                                           NaN
# girvan_mu3_0.gml                                           NaN
# girvan_mu4_0.gml                                           NaN
# girvan_mu5_0.gml                                           NaN
# girvan_mu6_0.gml                                           NaN
# girvan_mu7_0.gml                                           NaN
# girvan_mu8_0.gml                                           NaN
# karate.gml                                                 NaN
# lfr_10000_mu3_s_size_0.gml                            0.359159
# lfr_1000_mu1_b_0.gml                                  0.748702
# lfr_1000_mu1_s_0.gml                                  0.855293
# lfr_1000_mu2_b_0.gml                                  0.494058
# lfr_1000_mu2_s_0.gml                                  0.705586
# lfr_1000_mu3_b_0.gml                                  0.315953
# lfr_1000_mu3_s_0.gml                                  0.545655
# lfr_1000_mu3_s_size_0.gml                             0.539882
# lfr_1000_mu4_b_0.gml                                  0.168425
# lfr_1000_mu4_s_0.gml                                  0.320507
# lfr_1000_mu5_b_0.gml                                  0.104564
# lfr_1000_mu5_s_0.gml                                  0.144591
# lfr_1000_mu6_b_0.gml                                  0.088581
# lfr_1000_mu6_s_0.gml                                  0.102864
# lfr_2000_mu3_s_size_0.gml                             0.561170
# lfr_3000_mu3_s_size_0.gml                             0.563562
# lfr_4000_mu3_s_size_0.gml                             0.585530
# lfr_5000_mu1_b_0.gml                                       NaN
# lfr_5000_mu1_s_0.gml                                  0.847522
# lfr_5000_mu2_b_0.gml                                       NaN
# lfr_5000_mu2_s_0.gml                                  0.715580
# lfr_5000_mu3_b_0.gml                                       NaN
# lfr_5000_mu3_s_0.gml                                  0.596257
# lfr_5000_mu3_s_size_0.gml                             0.595100
# lfr_5000_mu4_b_0.gml                                       NaN
# lfr_5000_mu4_s_0.gml                                  0.501290
# lfr_5000_mu5_b_0.gml                                  0.342049
# lfr_5000_mu5_s_0.gml                                  0.427704
# lfr_5000_mu6_b_0.gml                                  0.288235
# lfr_5000_mu6_s_0.gml                                  0.366758
# lfr_6000_mu3_s_size_0.gml                             0.597865
# lfr_7000_mu3_s_size_0.gml                             0.607412
# lfr_8000_mu3_s_size_0.gml                             0.611417
# lfr_9000_mu3_s_size_0.gml                             0.614500
#
# params_file                 impl_GANET/default.properties  \
# filename
# dolphins.gml                                          NaN
# football.gml                                     0.923358
# girvan_mu1_0.gml                                 1.000000
# girvan_mu2_0.gml                                 1.000000
# girvan_mu3_0.gml                                 0.035957
# girvan_mu4_0.gml                                 0.000000
# girvan_mu5_0.gml                                 0.000000
# girvan_mu6_0.gml                                 0.000000
# girvan_mu7_0.gml                                 0.000000
# girvan_mu8_0.gml                                 0.000000
# karate.gml                                       0.650967
# lfr_10000_mu3_s_size_0.gml                       0.371252
# lfr_1000_mu1_b_0.gml                             0.866875
# lfr_1000_mu1_s_0.gml                             0.934731
# lfr_1000_mu2_b_0.gml                             0.629745
# lfr_1000_mu2_s_0.gml                             0.827131
# lfr_1000_mu3_b_0.gml                             0.411540
# lfr_1000_mu3_s_0.gml                             0.670480
# lfr_1000_mu3_s_size_0.gml                        0.674468
# lfr_1000_mu4_b_0.gml                             0.141490
# lfr_1000_mu4_s_0.gml                             0.469199
# lfr_1000_mu5_b_0.gml                             0.087208
# lfr_1000_mu5_s_0.gml                             0.150757
# lfr_1000_mu6_b_0.gml                             0.058907
# lfr_1000_mu6_s_0.gml                             0.093916
# lfr_2000_mu3_s_size_0.gml                        0.636700
# lfr_3000_mu3_s_size_0.gml                        0.632888
# lfr_4000_mu3_s_size_0.gml                        0.633328
# lfr_5000_mu1_b_0.gml                             0.810031
# lfr_5000_mu1_s_0.gml                             0.887494
# lfr_5000_mu2_b_0.gml                             0.657592
# lfr_5000_mu2_s_0.gml                             0.757807
# lfr_5000_mu3_b_0.gml                             0.502020
# lfr_5000_mu3_s_0.gml                             0.636998
# lfr_5000_mu3_s_size_0.gml                        0.642432
# lfr_5000_mu4_b_0.gml                             0.426943
# lfr_5000_mu4_s_0.gml                             0.528258
# lfr_5000_mu5_b_0.gml                             0.376755
# lfr_5000_mu5_s_0.gml                             0.459731
# lfr_5000_mu6_b_0.gml                             0.327088
# lfr_5000_mu6_s_0.gml                             0.412413
# lfr_6000_mu3_s_size_0.gml                        0.641358
# lfr_7000_mu3_s_size_0.gml                        0.644904
# lfr_8000_mu3_s_size_0.gml                        0.642010
# lfr_9000_mu3_s_size_0.gml                        0.643179
#
# params_file                 impl_GANET/high_elite.properties  \
# filename
# dolphins.gml                                             NaN
# football.gml                                             NaN
# girvan_mu1_0.gml                                         NaN
# girvan_mu2_0.gml                                         NaN
# girvan_mu3_0.gml                                         NaN
# girvan_mu4_0.gml                                         NaN
# girvan_mu5_0.gml                                         NaN
# girvan_mu6_0.gml                                         NaN
# girvan_mu7_0.gml                                         NaN
# girvan_mu8_0.gml                                         NaN
# karate.gml                                               NaN
# lfr_10000_mu3_s_size_0.gml                          0.360884
# lfr_1000_mu1_b_0.gml                                0.832765
# lfr_1000_mu1_s_0.gml                                0.914118
# lfr_1000_mu2_b_0.gml                                0.590744
# lfr_1000_mu2_s_0.gml                                0.789624
# lfr_1000_mu3_b_0.gml                                0.388165
# lfr_1000_mu3_s_0.gml                                0.624793
# lfr_1000_mu3_s_size_0.gml                           0.629271
# lfr_1000_mu4_b_0.gml                                0.162889
# lfr_1000_mu4_s_0.gml                                0.447024
# lfr_1000_mu5_b_0.gml                                0.096274
# lfr_1000_mu5_s_0.gml                                0.124773
# lfr_1000_mu6_b_0.gml                                0.077062
# lfr_1000_mu6_s_0.gml                                0.117577
# lfr_2000_mu3_s_size_0.gml                           0.604976
# lfr_3000_mu3_s_size_0.gml                           0.609952
# lfr_4000_mu3_s_size_0.gml                           0.618801
# lfr_5000_mu1_b_0.gml                                     NaN
# lfr_5000_mu1_s_0.gml                                0.874719
# lfr_5000_mu2_b_0.gml                                     NaN
# lfr_5000_mu2_s_0.gml                                0.745272
# lfr_5000_mu3_b_0.gml                                     NaN
# lfr_5000_mu3_s_0.gml                                0.615211
# lfr_5000_mu3_s_size_0.gml                           0.621431
# lfr_5000_mu4_b_0.gml                                     NaN
# lfr_5000_mu4_s_0.gml                                0.516079
# lfr_5000_mu5_b_0.gml                                0.360565
# lfr_5000_mu5_s_0.gml                                0.448779
# lfr_5000_mu6_b_0.gml                                0.315051
# lfr_5000_mu6_s_0.gml                                0.392531
# lfr_6000_mu3_s_size_0.gml                           0.626302
# lfr_7000_mu3_s_size_0.gml                           0.634361
# lfr_8000_mu3_s_size_0.gml                           0.630266
# lfr_9000_mu3_s_size_0.gml                           0.632822
#
# params_file                 impl_GANET/large.properties  \
# filename
# dolphins.gml                                        NaN
# football.gml                                   0.930813
# girvan_mu1_0.gml                               1.000000
# girvan_mu2_0.gml                               1.000000
# girvan_mu3_0.gml                               0.241103
# girvan_mu4_0.gml                               0.000000
# girvan_mu5_0.gml                               0.000000
# girvan_mu6_0.gml                               0.000000
# girvan_mu7_0.gml                               0.000000
# girvan_mu8_0.gml                               0.000000
# karate.gml                                     0.636925
# lfr_10000_mu3_s_size_0.gml                     0.420213
# lfr_1000_mu1_b_0.gml                           0.980016
# lfr_1000_mu1_s_0.gml                           0.995555
# lfr_1000_mu2_b_0.gml                           0.918391
# lfr_1000_mu2_s_0.gml                           0.990135
# lfr_1000_mu3_b_0.gml                           0.732766
# lfr_1000_mu3_s_0.gml                           0.944315
# lfr_1000_mu3_s_size_0.gml                      0.943294
# lfr_1000_mu4_b_0.gml                           0.218297
# lfr_1000_mu4_s_0.gml                           0.796977
# lfr_1000_mu5_b_0.gml                           0.105758
# lfr_1000_mu5_s_0.gml                           0.164837
# lfr_1000_mu6_b_0.gml                           0.057365
# lfr_1000_mu6_s_0.gml                           0.108370
# lfr_2000_mu3_s_size_0.gml                      0.864142
# lfr_3000_mu3_s_size_0.gml                      0.813753
# lfr_4000_mu3_s_size_0.gml                      0.782710
# lfr_5000_mu1_b_0.gml                           0.910538
# lfr_5000_mu1_s_0.gml                           0.958788
# lfr_5000_mu2_b_0.gml                           0.792439
# lfr_5000_mu2_s_0.gml                           0.882499
# lfr_5000_mu3_b_0.gml                           0.626695
# lfr_5000_mu3_s_0.gml                           0.775898
# lfr_5000_mu3_s_size_0.gml                      0.776084
# lfr_5000_mu4_b_0.gml                           0.532026
# lfr_5000_mu4_s_0.gml                           0.647691
# lfr_5000_mu5_b_0.gml                           0.487276
# lfr_5000_mu5_s_0.gml                           0.575687
# lfr_5000_mu6_b_0.gml                           0.450229
# lfr_5000_mu6_s_0.gml                           0.532801
# lfr_6000_mu3_s_size_0.gml                      0.760683
# lfr_7000_mu3_s_size_0.gml                      0.756665
# lfr_8000_mu3_s_size_0.gml                      0.745822
# lfr_9000_mu3_s_size_0.gml                      0.736904
#
# params_file                 impl_GANET/low_cross_high_m.properties
# filename
# dolphins.gml                                                   NaN
# football.gml                                                   NaN
# girvan_mu1_0.gml                                               NaN
# girvan_mu2_0.gml                                               NaN
# girvan_mu3_0.gml                                               NaN
# girvan_mu4_0.gml                                               NaN
# girvan_mu5_0.gml                                               NaN
# girvan_mu6_0.gml                                               NaN
# girvan_mu7_0.gml                                               NaN
# girvan_mu8_0.gml                                               NaN
# karate.gml                                                     NaN
# lfr_10000_mu3_s_size_0.gml                                0.356084
# lfr_1000_mu1_b_0.gml                                      0.717836
# lfr_1000_mu1_s_0.gml                                      0.823007
# lfr_1000_mu2_b_0.gml                                      0.464105
# lfr_1000_mu2_s_0.gml                                      0.660465
# lfr_1000_mu3_b_0.gml                                      0.291137
# lfr_1000_mu3_s_0.gml                                      0.511868
# lfr_1000_mu3_s_size_0.gml                                 0.516389
# lfr_1000_mu4_b_0.gml                                      0.136763
# lfr_1000_mu4_s_0.gml                                      0.261156
# lfr_1000_mu5_b_0.gml                                      0.102360
# lfr_1000_mu5_s_0.gml                                      0.131227
# lfr_1000_mu6_b_0.gml                                      0.082680
# lfr_1000_mu6_s_0.gml                                      0.109004
# lfr_2000_mu3_s_size_0.gml                                 0.548671
# lfr_3000_mu3_s_size_0.gml                                 0.555048
# lfr_4000_mu3_s_size_0.gml                                 0.576693
# lfr_5000_mu1_b_0.gml                                           NaN
# lfr_5000_mu1_s_0.gml                                      0.838640
# lfr_5000_mu2_b_0.gml                                           NaN
# lfr_5000_mu2_s_0.gml                                      0.700349
# lfr_5000_mu3_b_0.gml                                           NaN
# lfr_5000_mu3_s_0.gml                                      0.584279
# lfr_5000_mu3_s_size_0.gml                                 0.585115
# lfr_5000_mu4_b_0.gml                                           NaN
# lfr_5000_mu4_s_0.gml                                      0.473505
# lfr_5000_mu5_b_0.gml                                      0.338299
# lfr_5000_mu5_s_0.gml                                      0.414045
# lfr_5000_mu6_b_0.gml                                      0.290542
# lfr_5000_mu6_s_0.gml                                      0.362869
# lfr_6000_mu3_s_size_0.gml                                 0.581605
# lfr_7000_mu3_s_size_0.gml                                 0.599469
# lfr_8000_mu3_s_size_0.gml                                 0.599898
# lfr_9000_mu3_s_size_0.gml                                 0.606181

# %%
with open('ganet.tex','w') as tf:
    tf.write(ganet_valtable.to_latex())

# %%
gacd_valtable = gacd.groupby(['filename','params_file'], sort=False)['nmi'].mean().reset_index().pivot('filename', 'params_file', 'nmi')
gacd_valtable
# Out:
# params_file                 impl_GACD/default.properties  \
# filename
# dolphins.gml                                         NaN
# football.gml                                    0.777141
# girvan_mu1_0.gml                                1.000000
# girvan_mu2_0.gml                                0.979866
# girvan_mu3_0.gml                                0.805293
# girvan_mu4_0.gml                                0.523480
# girvan_mu5_0.gml                                0.152782
# girvan_mu6_0.gml                                0.078530
# girvan_mu7_0.gml                                0.061151
# girvan_mu8_0.gml                                0.042013
# karate.gml                                      0.687263
# lfr_10000_mu3_s_size_0.gml                      0.325895
# lfr_1000_mu1_b_0.gml                            0.771596
# lfr_1000_mu1_s_0.gml                            0.846315
# lfr_1000_mu2_b_0.gml                            0.534279
# lfr_1000_mu2_s_0.gml                            0.688223
# lfr_1000_mu3_b_0.gml                            0.402204
# lfr_1000_mu3_s_0.gml                            0.538599
# lfr_1000_mu3_s_size_0.gml                       0.537149
# lfr_1000_mu4_b_0.gml                            0.310047
# lfr_1000_mu4_s_0.gml                            0.409071
# lfr_1000_mu5_b_0.gml                            0.231277
# lfr_1000_mu5_s_0.gml                            0.332696
# lfr_1000_mu6_b_0.gml                            0.178357
# lfr_1000_mu6_s_0.gml                            0.293294
# lfr_2000_mu3_s_size_0.gml                       0.519002
# lfr_3000_mu3_s_size_0.gml                       0.533768
# lfr_4000_mu3_s_size_0.gml                       0.565830
# lfr_5000_mu1_s_0.gml                            0.824710
# lfr_5000_mu2_s_0.gml                            0.678900
# lfr_5000_mu3_s_0.gml                            0.563697
# lfr_5000_mu3_s_size_0.gml                       0.559483
# lfr_5000_mu4_s_0.gml                            0.472500
# lfr_5000_mu5_b_0.gml                            0.318851
# lfr_5000_mu5_s_0.gml                            0.399145
# lfr_5000_mu6_b_0.gml                            0.272638
# lfr_5000_mu6_s_0.gml                            0.364203
# lfr_6000_mu3_s_size_0.gml                       0.568888
# lfr_7000_mu3_s_size_0.gml                       0.577109
# lfr_8000_mu3_s_size_0.gml                       0.581527
# lfr_9000_mu3_s_size_0.gml                       0.593053
#
# params_file                 impl_GACD/large.properties  \
# filename
# dolphins.gml                                       NaN
# football.gml                                  0.830657
# girvan_mu1_0.gml                              1.000000
# girvan_mu2_0.gml                              0.971664
# girvan_mu3_0.gml                              0.798257
# girvan_mu4_0.gml                              0.523709
# girvan_mu5_0.gml                              0.198201
# girvan_mu6_0.gml                              0.089735
# girvan_mu7_0.gml                              0.040563
# girvan_mu8_0.gml                              0.028933
# karate.gml                                    0.687263
# lfr_10000_mu3_s_size_0.gml                    0.323713
# lfr_1000_mu1_b_0.gml                          0.784563
# lfr_1000_mu1_s_0.gml                          0.836506
# lfr_1000_mu2_b_0.gml                          0.561023
# lfr_1000_mu2_s_0.gml                          0.688521
# lfr_1000_mu3_b_0.gml                          0.393820
# lfr_1000_mu3_s_0.gml                          0.540994
# lfr_1000_mu3_s_size_0.gml                     0.532944
# lfr_1000_mu4_b_0.gml                          0.307422
# lfr_1000_mu4_s_0.gml                          0.403475
# lfr_1000_mu5_b_0.gml                          0.241211
# lfr_1000_mu5_s_0.gml                          0.328349
# lfr_1000_mu6_b_0.gml                          0.165416
# lfr_1000_mu6_s_0.gml                          0.286686
# lfr_2000_mu3_s_size_0.gml                     0.539289
# lfr_3000_mu3_s_size_0.gml                     0.535083
# lfr_4000_mu3_s_size_0.gml                     0.546624
# lfr_5000_mu1_s_0.gml                          0.826846
# lfr_5000_mu2_s_0.gml                          0.681646
# lfr_5000_mu3_s_0.gml                          0.565310
# lfr_5000_mu3_s_size_0.gml                     0.557350
# lfr_5000_mu4_s_0.gml                          0.457411
# lfr_5000_mu5_b_0.gml                          0.313645
# lfr_5000_mu5_s_0.gml                          0.407927
# lfr_5000_mu6_b_0.gml                          0.275505
# lfr_5000_mu6_s_0.gml                          0.354392
# lfr_6000_mu3_s_size_0.gml                     0.573836
# lfr_7000_mu3_s_size_0.gml                     0.579336
# lfr_8000_mu3_s_size_0.gml                     0.572247
# lfr_9000_mu3_s_size_0.gml                     0.587939
#
# params_file                 impl_GACD/low_mut_high_cross.properties
# filename
# dolphins.gml                                                    NaN
# football.gml                                               0.812103
# girvan_mu1_0.gml                                           1.000000
# girvan_mu2_0.gml                                           0.989942
# girvan_mu3_0.gml                                           0.824674
# girvan_mu4_0.gml                                           0.551380
# girvan_mu5_0.gml                                           0.172146
# girvan_mu6_0.gml                                           0.092851
# girvan_mu7_0.gml                                           0.045473
# girvan_mu8_0.gml                                           0.030697
# karate.gml                                                 0.687263
# lfr_10000_mu3_s_size_0.gml                                 0.320729
# lfr_1000_mu1_b_0.gml                                       0.779582
# lfr_1000_mu1_s_0.gml                                       0.842488
# lfr_1000_mu2_b_0.gml                                       0.540230
# lfr_1000_mu2_s_0.gml                                       0.682084
# lfr_1000_mu3_b_0.gml                                       0.381347
# lfr_1000_mu3_s_0.gml                                       0.538016
# lfr_1000_mu3_s_size_0.gml                                  0.531581
# lfr_1000_mu4_b_0.gml                                       0.302515
# lfr_1000_mu4_s_0.gml                                       0.428635
# lfr_1000_mu5_b_0.gml                                       0.235029
# lfr_1000_mu5_s_0.gml                                       0.324954
# lfr_1000_mu6_b_0.gml                                       0.158798
# lfr_1000_mu6_s_0.gml                                       0.287189
# lfr_2000_mu3_s_size_0.gml                                  0.531747
# lfr_3000_mu3_s_size_0.gml                                  0.539607
# lfr_4000_mu3_s_size_0.gml                                  0.537489
# lfr_5000_mu1_s_0.gml                                       0.823104
# lfr_5000_mu2_s_0.gml                                       0.685678
# lfr_5000_mu3_s_0.gml                                       0.561590
# lfr_5000_mu3_s_size_0.gml                                  0.561858
# lfr_5000_mu4_s_0.gml                                       0.457527
# lfr_5000_mu5_b_0.gml                                       0.316660
# lfr_5000_mu5_s_0.gml                                       0.403367
# lfr_5000_mu6_b_0.gml                                       0.269461
# lfr_5000_mu6_s_0.gml                                       0.343474
# lfr_6000_mu3_s_size_0.gml                                  0.566224
# lfr_7000_mu3_s_size_0.gml                                  0.579673
# lfr_8000_mu3_s_size_0.gml                                  0.578679
# lfr_9000_mu3_s_size_0.gml                                  0.583258

# %%
with open('gacd.tex','w') as tf:
    tf.write(ganet_valtable.to_latex())

# %%
tbga_valtable = tbga.groupby(['filename','params_file'], sort=False)['nmi'].mean().reset_index().pivot('filename', 'params_file', 'nmi')
tbga_valtable
# Out:
# params_file                 impl_TasginGA/default.properties  \
# filename
# dolphins.gml                                             NaN
# football.gml                                        0.741184
# girvan_mu1_0.gml                                    1.000000
# girvan_mu2_0.gml                                    0.990121
# girvan_mu3_0.gml                                    0.901963
# girvan_mu4_0.gml                                    0.624702
# girvan_mu5_0.gml                                    0.147785
# girvan_mu6_0.gml                                    0.076576
# girvan_mu7_0.gml                                    0.044218
# girvan_mu8_0.gml                                    0.026610
# karate.gml                                          0.678423
# lfr_10000_mu3_s_size_0.gml                          0.266617
# lfr_1000_mu1_b_0.gml                                0.944796
# lfr_1000_mu1_s_0.gml                                0.917641
# lfr_1000_mu2_b_0.gml                                0.807591
# lfr_1000_mu2_s_0.gml                                0.804872
# lfr_1000_mu3_b_0.gml                                0.656177
# lfr_1000_mu3_s_0.gml                                0.660195
# lfr_1000_mu3_s_size_0.gml                           0.656859
# lfr_1000_mu4_b_0.gml                                0.331574
# lfr_1000_mu4_s_0.gml                                0.396012
# lfr_1000_mu5_b_0.gml                                0.225200
# lfr_1000_mu5_s_0.gml                                0.288316
# lfr_1000_mu6_b_0.gml                                0.134398
# lfr_1000_mu6_s_0.gml                                0.234963
# lfr_2000_mu3_s_size_0.gml                           0.650346
# lfr_3000_mu3_s_size_0.gml                           0.655390
# lfr_4000_mu3_s_size_0.gml                           0.669950
# lfr_5000_mu1_b_0.gml                                0.897490
# lfr_5000_mu1_s_0.gml                                0.897496
# lfr_5000_mu2_b_0.gml                                0.774828
# lfr_5000_mu2_s_0.gml                                0.784770
# lfr_5000_mu3_b_0.gml                                0.647095
# lfr_5000_mu3_s_0.gml                                0.671965
# lfr_5000_mu3_s_size_0.gml                           0.659444
# lfr_5000_mu4_b_0.gml                                0.438830
# lfr_5000_mu4_s_0.gml                                0.497231
# lfr_5000_mu5_b_0.gml                                0.297197
# lfr_5000_mu5_s_0.gml                                0.378444
# lfr_5000_mu6_b_0.gml                                0.247211
# lfr_5000_mu6_s_0.gml                                0.315262
# lfr_6000_mu3_s_size_0.gml                           0.668564
# lfr_7000_mu3_s_size_0.gml                           0.676924
# lfr_8000_mu3_s_size_0.gml                           0.683656
# lfr_9000_mu3_s_size_0.gml                           0.685235
#
# params_file                 impl_TasginGA/high_elite.properties  \
# filename
# dolphins.gml                                                NaN
# football.gml                                           0.715898
# girvan_mu1_0.gml                                       1.000000
# girvan_mu2_0.gml                                       0.938123
# girvan_mu3_0.gml                                       0.780120
# girvan_mu4_0.gml                                       0.506629
# girvan_mu5_0.gml                                       0.160739
# girvan_mu6_0.gml                                       0.061667
# girvan_mu7_0.gml                                       0.050555
# girvan_mu8_0.gml                                       0.037776
# karate.gml                                             0.688485
# lfr_10000_mu3_s_size_0.gml                             0.227321
# lfr_1000_mu1_b_0.gml                                   0.923356
# lfr_1000_mu1_s_0.gml                                   0.891162
# lfr_1000_mu2_b_0.gml                                   0.765689
# lfr_1000_mu2_s_0.gml                                   0.761403
# lfr_1000_mu3_b_0.gml                                   0.597478
# lfr_1000_mu3_s_0.gml                                   0.607600
# lfr_1000_mu3_s_size_0.gml                              0.610919
# lfr_1000_mu4_b_0.gml                                   0.262427
# lfr_1000_mu4_s_0.gml                                   0.358641
# lfr_1000_mu5_b_0.gml                                   0.168157
# lfr_1000_mu5_s_0.gml                                   0.244587
# lfr_1000_mu6_b_0.gml                                   0.116184
# lfr_1000_mu6_s_0.gml                                   0.192374
# lfr_2000_mu3_s_size_0.gml                              0.598863
# lfr_3000_mu3_s_size_0.gml                              0.607315
# lfr_4000_mu3_s_size_0.gml                              0.610598
# lfr_5000_mu1_b_0.gml                                   0.864147
# lfr_5000_mu1_s_0.gml                                   0.869132
# lfr_5000_mu2_b_0.gml                                   0.728826
# lfr_5000_mu2_s_0.gml                                   0.747121
# lfr_5000_mu3_b_0.gml                                   0.599618
# lfr_5000_mu3_s_0.gml                                   0.625865
# lfr_5000_mu3_s_size_0.gml                              0.621375
# lfr_5000_mu4_b_0.gml                                   0.365414
# lfr_5000_mu4_s_0.gml                                   0.435276
# lfr_5000_mu5_b_0.gml                                   0.247465
# lfr_5000_mu5_s_0.gml                                   0.334449
# lfr_5000_mu6_b_0.gml                                   0.197648
# lfr_5000_mu6_s_0.gml                                   0.263287
# lfr_6000_mu3_s_size_0.gml                              0.631834
# lfr_7000_mu3_s_size_0.gml                              0.633263
# lfr_8000_mu3_s_size_0.gml                              0.638224
# lfr_9000_mu3_s_size_0.gml                              0.642035
#
# params_file                 impl_TasginGA/high_init.properties  \
# filename
# dolphins.gml                                               NaN
# football.gml                                          0.739433
# girvan_mu1_0.gml                                      1.000000
# girvan_mu2_0.gml                                      0.977949
# girvan_mu3_0.gml                                      0.879055
# girvan_mu4_0.gml                                      0.602239
# girvan_mu5_0.gml                                      0.200079
# girvan_mu6_0.gml                                      0.076489
# girvan_mu7_0.gml                                      0.028483
# girvan_mu8_0.gml                                      0.026474
# karate.gml                                            0.687263
# lfr_10000_mu3_s_size_0.gml                            0.232009
# lfr_1000_mu1_b_0.gml                                  0.934695
# lfr_1000_mu1_s_0.gml                                  0.907026
# lfr_1000_mu2_b_0.gml                                  0.799624
# lfr_1000_mu2_s_0.gml                                  0.770115
# lfr_1000_mu3_b_0.gml                                  0.629369
# lfr_1000_mu3_s_0.gml                                  0.629787
# lfr_1000_mu3_s_size_0.gml                             0.630760
# lfr_1000_mu4_b_0.gml                                  0.288460
# lfr_1000_mu4_s_0.gml                                  0.386434
# lfr_1000_mu5_b_0.gml                                  0.186291
# lfr_1000_mu5_s_0.gml                                  0.259486
# lfr_1000_mu6_b_0.gml                                  0.108227
# lfr_1000_mu6_s_0.gml                                  0.194399
# lfr_2000_mu3_s_size_0.gml                             0.625561
# lfr_3000_mu3_s_size_0.gml                             0.618184
# lfr_4000_mu3_s_size_0.gml                             0.623122
# lfr_5000_mu1_b_0.gml                                  0.875075
# lfr_5000_mu1_s_0.gml                                  0.868131
# lfr_5000_mu2_b_0.gml                                  0.738134
# lfr_5000_mu2_s_0.gml                                  0.750238
# lfr_5000_mu3_b_0.gml                                  0.615826
# lfr_5000_mu3_s_0.gml                                  0.630319
# lfr_5000_mu3_s_size_0.gml                             0.624339
# lfr_5000_mu4_b_0.gml                                  0.382090
# lfr_5000_mu4_s_0.gml                                  0.452875
# lfr_5000_mu5_b_0.gml                                  0.250861
# lfr_5000_mu5_s_0.gml                                  0.333089
# lfr_5000_mu6_b_0.gml                                  0.189130
# lfr_5000_mu6_s_0.gml                                  0.270336
# lfr_6000_mu3_s_size_0.gml                             0.633273
# lfr_7000_mu3_s_size_0.gml                             0.642858
# lfr_8000_mu3_s_size_0.gml                             0.642072
# lfr_9000_mu3_s_size_0.gml                             0.647912
#
# params_file                 impl_TasginGA/high_mut.properties  \
# filename
# dolphins.gml                                              NaN
# football.gml                                         0.741707
# girvan_mu1_0.gml                                     1.000000
# girvan_mu2_0.gml                                     0.964862
# girvan_mu3_0.gml                                     0.896621
# girvan_mu4_0.gml                                     0.578908
# girvan_mu5_0.gml                                     0.179540
# girvan_mu6_0.gml                                     0.085948
# girvan_mu7_0.gml                                     0.031372
# girvan_mu8_0.gml                                     0.029247
# karate.gml                                           0.688485
# lfr_10000_mu3_s_size_0.gml                           0.264135
# lfr_1000_mu1_b_0.gml                                 0.945835
# lfr_1000_mu1_s_0.gml                                 0.914916
# lfr_1000_mu2_b_0.gml                                 0.811761
# lfr_1000_mu2_s_0.gml                                 0.795364
# lfr_1000_mu3_b_0.gml                                 0.647830
# lfr_1000_mu3_s_0.gml                                 0.645352
# lfr_1000_mu3_s_size_0.gml                            0.648168
# lfr_1000_mu4_b_0.gml                                 0.325454
# lfr_1000_mu4_s_0.gml                                 0.395512
# lfr_1000_mu5_b_0.gml                                 0.217667
# lfr_1000_mu5_s_0.gml                                 0.288867
# lfr_1000_mu6_b_0.gml                                 0.138578
# lfr_1000_mu6_s_0.gml                                 0.241564
# lfr_2000_mu3_s_size_0.gml                            0.653308
# lfr_3000_mu3_s_size_0.gml                            0.652423
# lfr_4000_mu3_s_size_0.gml                            0.652831
# lfr_5000_mu1_b_0.gml                                 0.899769
# lfr_5000_mu1_s_0.gml                                 0.893212
# lfr_5000_mu2_b_0.gml                                 0.772707
# lfr_5000_mu2_s_0.gml                                 0.785012
# lfr_5000_mu3_b_0.gml                                 0.642259
# lfr_5000_mu3_s_0.gml                                 0.660654
# lfr_5000_mu3_s_size_0.gml                            0.669571
# lfr_5000_mu4_b_0.gml                                 0.423005
# lfr_5000_mu4_s_0.gml                                 0.497711
# lfr_5000_mu5_b_0.gml                                 0.303800
# lfr_5000_mu5_s_0.gml                                 0.372747
# lfr_5000_mu6_b_0.gml                                 0.240095
# lfr_5000_mu6_s_0.gml                                 0.313558
# lfr_6000_mu3_s_size_0.gml                            0.670897
# lfr_7000_mu3_s_size_0.gml                            0.680211
# lfr_8000_mu3_s_size_0.gml                            0.683857
# lfr_9000_mu3_s_size_0.gml                            0.688298
#
# params_file                 impl_TasginGA/large.properties
# filename
# dolphins.gml                                           NaN
# football.gml                                      0.791795
# girvan_mu1_0.gml                                  1.000000
# girvan_mu2_0.gml                                  1.000000
# girvan_mu3_0.gml                                  1.000000
# girvan_mu4_0.gml                                  0.830322
# girvan_mu5_0.gml                                  0.260860
# girvan_mu6_0.gml                                  0.083643
# girvan_mu7_0.gml                                  0.031204
# girvan_mu8_0.gml                                  0.019529
# karate.gml                                        0.687263
# lfr_10000_mu3_s_size_0.gml                        0.263370
# lfr_1000_mu1_b_0.gml                              0.973826
# lfr_1000_mu1_s_0.gml                              0.943347
# lfr_1000_mu2_b_0.gml                              0.911146
# lfr_1000_mu2_s_0.gml                              0.852972
# lfr_1000_mu3_b_0.gml                              0.797824
# lfr_1000_mu3_s_0.gml                              0.749043
# lfr_1000_mu3_s_size_0.gml                         0.734812
# lfr_1000_mu4_b_0.gml                              0.417021
# lfr_1000_mu4_s_0.gml                              0.494253
# lfr_1000_mu5_b_0.gml                              0.252298
# lfr_1000_mu5_s_0.gml                              0.339055
# lfr_1000_mu6_b_0.gml                              0.160547
# lfr_1000_mu6_s_0.gml                              0.272810
# lfr_2000_mu3_s_size_0.gml                         0.705827
# lfr_3000_mu3_s_size_0.gml                         0.700778
# lfr_4000_mu3_s_size_0.gml                         0.688912
# lfr_5000_mu1_b_0.gml                              0.906624
# lfr_5000_mu1_s_0.gml                              0.901649
# lfr_5000_mu2_b_0.gml                              0.800696
# lfr_5000_mu2_s_0.gml                              0.800473
# lfr_5000_mu3_b_0.gml                              0.692395
# lfr_5000_mu3_s_0.gml                              0.697254
# lfr_5000_mu3_s_size_0.gml                         0.696568
# lfr_5000_mu4_b_0.gml                              0.481651
# lfr_5000_mu4_s_0.gml                              0.522983
# lfr_5000_mu5_b_0.gml                              0.305233
# lfr_5000_mu5_s_0.gml                              0.387913
# lfr_5000_mu6_b_0.gml                              0.249650
# lfr_5000_mu6_s_0.gml                              0.322243
# lfr_6000_mu3_s_size_0.gml                         0.694840
# lfr_7000_mu3_s_size_0.gml                         0.701481
# lfr_8000_mu3_s_size_0.gml                         0.697694
# lfr_9000_mu3_s_size_0.gml                         0.701682

# %%
with open('tasgin.tex','w') as tf:
    tf.write(tbga_valtable.to_latex())

# %%
def
