# %%
# %matplotlib inline
import os
import igraph as ig
import pandas as pd
from scipy import stats
import numpy as np
import sqlite3
import matplotlib.pyplot as plt

# %% [markdown]
# ## Analysis of Genetic Algorithms for Community Detection in Complex Networks

# %%
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("ClusterResults.db")
df = pd.read_sql_query("SELECT * from ClusterResults", con)

# Verify that result of SQL query is stored in the dataframe
con.close()
df.head()
# Out:
#    algo            seed                                               file  \
# 0  gals  13369360549290  D:/alien-pineapple/benchmark_gen/gml_files/ben...
# 1  gals  13369360549290  D:/alien-pineapple/benchmark_gen/gml_files/ben...
# 2  gals  13369360549290  D:/alien-pineapple/benchmark_gen/gml_files/ben...
# 3  gals  13369360549290  D:/alien-pineapple/benchmark_gen/gml_files/ben...
# 4  gals  13369360549290  D:/alien-pineapple/benchmark_gen/gml_files/ben...
#
#                                       average_scores  \
# 0  0.44009612959866123\n0.5461974760784992\n0.605...
# 1  0.44102171729926565\n0.5457098792826734\n0.609...
# 2  0.4402410463825556\n0.5448017280194865\n0.6035...
# 3  0.4390068762765545\n0.545385871564504\n0.60710...
# 4  0.43838356561266134\n0.5446626617100198\n0.605...
#
#                                          best_scores         final_score  \
# 0  0.5421854674251742\n0.6269896726720868\n0.6793...  0.8174163816764717
# 1  0.5605900188715776\n0.6435192651567331\n0.6994...  0.8183975072639841
# 2  0.5558795911697045\n0.6299240468040519\n0.6866...   0.817829138322348
# 3  0.5386790824759569\n0.6246539036437487\n0.6933...  0.8119665565380684
# 4  0.5284876212325604\n0.6271894762815291\n0.7049...  0.8169301644245596
#
#                     params_file  \
# 0  impl_GALS/default.properties
# 1  impl_GALS/default.properties
# 2  impl_GALS/default.properties
# 3  impl_GALS/default.properties
# 4  impl_GALS/default.properties
#
#                                           membership  nmi  rand   vi
# 0  1,2,3,1,2,4,5,6,2,6,7,8,9,10,11,5,12,6,13,14,1...  0.0   0.0  0.0
# 1  1,2,3,1,2,4,5,6,2,6,7,8,9,10,11,5,12,6,13,14,1...  0.0   0.0  0.0
# 2  1,2,3,1,2,4,5,6,2,6,7,8,9,10,11,5,12,6,13,14,1...  0.0   0.0  0.0
# 3  1,2,3,1,2,4,5,6,2,6,7,8,9,10,11,5,12,6,13,14,1...  0.0   0.0  0.0
# 4  1,2,3,1,2,4,5,6,2,6,7,8,9,10,11,5,12,6,13,14,1...  0.0   0.0  0.0

# %%
df['membership'] = df['membership'].apply(lambda s: map(int, s.split(',')))
df['best_scores'] = df['best_scores'].apply(lambda s: map(float, s.split('\n')))
df['average_scores'] = df['average_scores'].apply(lambda s: map(float, s.split('\n')))

# %%
df['filename'] = df['file'].apply(lambda s: os.path.basename(s))

# %%
def getTrueComs(file):
    true_file = file + ".coms"
    if os.path.exists(true_file):
        data = pd.read_csv(true_file, sep='\t', header=None)
        return list(data[1].as_matrix())
    else:
        return []

# %%
df['true_membership'] = df['file'].apply(lambda s: getTrueComs(s))

# %% [markdown]
# ## Comparison Metrics
#
# @article{rand1971,
#   added-at = {2006-03-21T11:09:44.000+0100},
#   author = {Rand, W.M.},
#   biburl = {https://www.bibsonomy.org/bibtex/2fd52548cb4bcd8e83dd27e4b55eff1f3/hotho},
#   interhash = {1afaf0170bc705a9e49b625f67679ee2},
#   intrahash = {fd52548cb4bcd8e83dd27e4b55eff1f3},
#   journal = {Journal of the American Statistical Association },
#   keywords = {cluster clustering criteria evaluation index rand},
#   number = 336,
#   pages = {846-850},
#   timestamp = {2007-09-18T14:44:34.000+0200},
#   title = {Objective criteria for the evaluation of clustering methods},
#   volume = 66,
#   year = 1971
# }

# %%
df['nmi'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="nmi"), axis=1)

df['vi'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="vi"), axis=1)

df['rand'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="rand"), axis=1)

df['adjusted_rand'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="adjusted_rand"), axis=1)

df['split_join'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="split-join"), axis=1)

# %%
df.head()
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
def identifyConverge(vals):
    """find the earliest occurance of the maximum value in a list
    """
    best = vals[-1]
    if vals[0] == best:
        return 0
    for i in range(len(vals)):
        if vals[i] == best:
            return i

# %%
df['converge_gen'] = df['best_scores'].apply(identifyConverge)
df['gens'] = df['best_scores'].apply(len)

# %%
def extract_size(name):
    file = str(name.split('/')[-1])
    size = None
    if 'lfr' in file:
        size = file.split('_')[1]
    elif 'girvan' in file:
        size = 128
    
    return size
    
    
def extract_mu(name):
    file = str(name.split('/')[-1])
    mu = None
    if 'mu' in file:
        mu = file.split('_')[2]
        mu = mu[2:]
    return mu


def extract_kout(name):
    file = str(name.split('/')[-1])
    mu = None
    if 'kout' in file:
        mu = file.split('_')[2]
    return mu


df['short_file'] = df['file'].apply(lambda s: str(s.split('/')[-1]))
df['size'] = df['file'].apply(lambda s: extract_size(s))
df['mu'] = df['file'].apply(lambda s: extract_mu(s))
df['kout'] = df['file'].apply(lambda s: extract_kout(s))

# %%
gals = df.loc[lambda dd: dd['algo'] == 'gals']
gacd = df.loc[lambda dd: dd['algo'] == 'gacd']
tbga = df.loc[lambda dd: dd['algo'] == 'tasgin']
ganet = df.loc[lambda dd: dd['algo'] == 'ganet']

# %%
def highlight_max(s):
    """
    highlight the maximum in a Series yellow.
    """
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
gals_valtable = gals.groupby(['filename','params_file'], sort=False)['nmi'].mean().reset_index().pivot('filename', 'params_file', 'nmi').reset_index()
gals_valtable
# Out:
# params_file                    filename  impl_GALS/default.properties  \
# 0                          dolphins.gml                           NaN
# 1                          football.gml                      0.884197
# 2                  girvan_kout_10_0.gml                      0.088649
# 3                  girvan_kout_11_0.gml                      0.066167
# 4                  girvan_kout_12_0.gml                      0.048254
# 5                  girvan_kout_13_0.gml                      0.037166
# 6                  girvan_kout_14_0.gml                      0.043141
# 7                  girvan_kout_15_0.gml                      0.028475
# 8                   girvan_kout_1_0.gml                      1.000000
# 9                   girvan_kout_2_0.gml                      1.000000
# 10                  girvan_kout_3_0.gml                      1.000000
# 11                  girvan_kout_4_0.gml                      1.000000
# 12                  girvan_kout_5_0.gml                      1.000000
# 13                  girvan_kout_6_0.gml                      0.987037
# 14                  girvan_kout_7_0.gml                      0.648537
# 15                  girvan_kout_8_0.gml                      0.220714
# 16                  girvan_kout_9_0.gml                      0.135001
# 17                           karate.gml                      0.687263
# 18           lfr_10000_mu3_s_size_0.gml                      0.463327
# 19                 lfr_1000_mu1_b_0.gml                      0.966796
# 20                 lfr_1000_mu1_s_0.gml                      0.980739
# 21                 lfr_1000_mu2_b_0.gml                      0.949321
# 22                 lfr_1000_mu2_s_0.gml                      0.975224
# 23                 lfr_1000_mu3_b_0.gml                      0.948886
# 24                 lfr_1000_mu3_s_0.gml                      0.971365
# 25            lfr_1000_mu3_s_size_0.gml                      0.967344
# 26                 lfr_1000_mu4_b_0.gml                      0.933161
# 27                 lfr_1000_mu4_s_0.gml                      0.962047
# 28                 lfr_1000_mu5_b_0.gml                      0.817367
# 29                 lfr_1000_mu5_s_0.gml                      0.944168
# 30                 lfr_1000_mu6_b_0.gml                      0.299870
# 31                 lfr_1000_mu6_s_0.gml                      0.885697
# 32            lfr_2000_mu3_s_size_0.gml                      0.961451
# 33            lfr_3000_mu3_s_size_0.gml                      0.959306
# 34            lfr_4000_mu3_s_size_0.gml                      0.963106
# 35                 lfr_5000_mu1_b_0.gml                      0.955345
# 36                 lfr_5000_mu1_s_0.gml                      0.972248
# 37                 lfr_5000_mu2_b_0.gml                      0.946636
# 38                 lfr_5000_mu2_s_0.gml                      0.970798
# 39                 lfr_5000_mu3_b_0.gml                      0.942214
# 40                 lfr_5000_mu3_s_0.gml                      0.965941
# 41            lfr_5000_mu3_s_size_0.gml                      0.963194
# 42                 lfr_5000_mu4_b_0.gml                      0.930235
# 43                 lfr_5000_mu4_s_0.gml                      0.957966
# 44                 lfr_5000_mu5_b_0.gml                      0.914782
# 45                 lfr_5000_mu5_s_0.gml                      0.953025
# 46                 lfr_5000_mu6_b_0.gml                      0.828651
# 47                 lfr_5000_mu6_s_0.gml                      0.928525
# 48            lfr_6000_mu3_s_size_0.gml                      0.961252
# 49            lfr_7000_mu3_s_size_0.gml                      0.965348
# 50            lfr_8000_mu3_s_size_0.gml                      0.963959
# 51            lfr_9000_mu3_s_size_0.gml                      0.963254
# 52                         polblogs.gml                      0.337440
#
# params_file  impl_GALS/large.properties
# 0                                   NaN
# 1                              0.890416
# 2                              0.075525
# 3                              0.049541
# 4                              0.054290
# 5                              0.039309
# 6                              0.030553
# 7                              0.027144
# 8                              1.000000
# 9                              1.000000
# 10                             1.000000
# 11                             1.000000
# 12                             1.000000
# 13                             1.000000
# 14                             1.000000
# 15                             0.377049
# 16                             0.122960
# 17                             0.687263
# 18                             0.465023
# 19                             0.980734
# 20                             0.988564
# 21                             0.976316
# 22                             0.984858
# 23                             0.976910
# 24                             0.981804
# 25                             0.977601
# 26                             0.976841
# 27                             0.983707
# 28                             0.965582
# 29                             0.979189
# 30                             0.680946
# 31                             0.961898
# 32                             0.974215
# 33                             0.972721
# 34                             0.973085
# 35                             0.966581
# 36                             0.977519
# 37                             0.962035
# 38                             0.974929
# 39                             0.959152
# 40                             0.974659
# 41                             0.974675
# 42                             0.958733
# 43                             0.972302
# 44                             0.951444
# 45                             0.967280
# 46                             0.932788
# 47                             0.956891
# 48                             0.972582
# 49                             0.973670
# 50                             0.972437
# 51                             0.972042
# 52                             0.344648

# %%
with open('gals.tex','w') as tf:
    tf.write(gals_valtable.to_latex())

# %%
ganet_valtable = ganet.groupby(['filename','params_file'], sort=False)['nmi'].mean().reset_index().pivot('filename', 'params_file', 'nmi').reset_index()
ganet_valtable
# Out:
# params_file                    filename  impl_GANET/balanced_c_m.properties  \
# 0                          dolphins.gml                                 NaN
# 1                          football.gml                                 NaN
# 2                  girvan_kout_10_0.gml                            0.000000
# 3                  girvan_kout_11_0.gml                            0.000000
# 4                  girvan_kout_12_0.gml                            0.000000
# 5                  girvan_kout_13_0.gml                            0.000000
# 6                  girvan_kout_14_0.gml                            0.000000
# 7                  girvan_kout_15_0.gml                            0.000000
# 8                   girvan_kout_1_0.gml                            0.997483
# 9                   girvan_kout_2_0.gml                            0.922690
# 10                  girvan_kout_3_0.gml                            0.751589
# 11                  girvan_kout_4_0.gml                            0.324299
# 12                  girvan_kout_5_0.gml                            0.000000
# 13                  girvan_kout_6_0.gml                            0.000000
# 14                  girvan_kout_7_0.gml                            0.000000
# 15                  girvan_kout_8_0.gml                            0.000000
# 16                  girvan_kout_9_0.gml                            0.000000
# 17                           karate.gml                                 NaN
# 18           lfr_10000_mu3_s_size_0.gml                            0.359222
# 19                 lfr_1000_mu1_b_0.gml                            0.748702
# 20                 lfr_1000_mu1_s_0.gml                            0.855293
# 21                 lfr_1000_mu2_b_0.gml                            0.494058
# 22                 lfr_1000_mu2_s_0.gml                            0.705586
# 23                 lfr_1000_mu3_b_0.gml                            0.315953
# 24                 lfr_1000_mu3_s_0.gml                            0.545655
# 25            lfr_1000_mu3_s_size_0.gml                            0.538160
# 26                 lfr_1000_mu4_b_0.gml                            0.168425
# 27                 lfr_1000_mu4_s_0.gml                            0.320507
# 28                 lfr_1000_mu5_b_0.gml                            0.104564
# 29                 lfr_1000_mu5_s_0.gml                            0.144591
# 30                 lfr_1000_mu6_b_0.gml                            0.088581
# 31                 lfr_1000_mu6_s_0.gml                            0.102864
# 32            lfr_2000_mu3_s_size_0.gml                            0.560614
# 33            lfr_3000_mu3_s_size_0.gml                            0.566029
# 34            lfr_4000_mu3_s_size_0.gml                            0.583575
# 35                 lfr_5000_mu1_b_0.gml                                 NaN
# 36                 lfr_5000_mu1_s_0.gml                            0.847522
# 37                 lfr_5000_mu2_b_0.gml                                 NaN
# 38                 lfr_5000_mu2_s_0.gml                            0.715580
# 39                 lfr_5000_mu3_b_0.gml                                 NaN
# 40                 lfr_5000_mu3_s_0.gml                            0.596257
# 41            lfr_5000_mu3_s_size_0.gml                            0.597353
# 42                 lfr_5000_mu4_b_0.gml                                 NaN
# 43                 lfr_5000_mu4_s_0.gml                            0.501290
# 44                 lfr_5000_mu5_b_0.gml                            0.342049
# 45                 lfr_5000_mu5_s_0.gml                            0.427704
# 46                 lfr_5000_mu6_b_0.gml                            0.288235
# 47                 lfr_5000_mu6_s_0.gml                            0.366758
# 48            lfr_6000_mu3_s_size_0.gml                            0.599841
# 49            lfr_7000_mu3_s_size_0.gml                            0.607307
# 50            lfr_8000_mu3_s_size_0.gml                            0.611243
# 51            lfr_9000_mu3_s_size_0.gml                            0.612959
#
# params_file  impl_GANET/default.properties  impl_GANET/high_elite.properties  \
# 0                                      NaN                               NaN
# 1                                 0.923358                               NaN
# 2                                 0.000000                          0.000000
# 3                                 0.000000                          0.000000
# 4                                 0.000000                          0.000000
# 5                                 0.000000                          0.000000
# 6                                 0.000000                          0.000000
# 7                                 0.000000                          0.000000
# 8                                 1.000000                          1.000000
# 9                                 1.000000                          1.000000
# 10                                1.000000                          0.987749
# 11                                0.413270                          0.374743
# 12                                0.000000                          0.000000
# 13                                0.000000                          0.000000
# 14                                0.000000                          0.000000
# 15                                0.000000                          0.000000
# 16                                0.000000                          0.000000
# 17                                0.650967                               NaN
# 18                                0.371252                          0.363627
# 19                                0.866875                          0.832765
# 20                                0.934731                          0.914118
# 21                                0.629745                          0.590744
# 22                                0.827131                          0.789624
# 23                                0.411540                          0.388165
# 24                                0.670480                          0.624793
# 25                                0.674468                          0.624667
# 26                                0.141490                          0.162889
# 27                                0.469199                          0.447024
# 28                                0.087208                          0.096274
# 29                                0.150757                          0.124773
# 30                                0.058907                          0.077062
# 31                                0.093916                          0.117577
# 32                                0.636700                          0.607540
# 33                                0.632888                          0.609465
# 34                                0.633328                          0.616845
# 35                                0.810031                               NaN
# 36                                0.887494                          0.874719
# 37                                0.657592                               NaN
# 38                                0.757807                          0.745272
# 39                                0.502020                               NaN
# 40                                0.636998                          0.615211
# 41                                0.642432                          0.622511
# 42                                0.426943                               NaN
# 43                                0.528258                          0.516079
# 44                                0.376755                          0.360565
# 45                                0.459731                          0.448779
# 46                                0.327088                          0.315051
# 47                                0.412413                          0.392531
# 48                                0.641358                          0.623480
# 49                                0.644904                          0.633132
# 50                                0.642010                          0.630647
# 51                                0.643179                          0.633805
#
# params_file  impl_GANET/high_r.properties  impl_GANET/higher_r.properties  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                0.010120                        0.039699
# 3                                0.006953                        0.030228
# 4                                0.010660                        0.026523
# 5                                0.004973                        0.027051
# 6                                0.008069                        0.015506
# 7                                0.006643                        0.016396
# 8                                1.000000                        1.000000
# 9                                1.000000                        1.000000
# 10                               1.000000                        1.000000
# 11                               0.983324                        0.997483
# 12                               0.357000                        0.696308
# 13                               0.071655                        0.182857
# 14                               0.063633                        0.092414
# 15                               0.009586                        0.051204
# 16                               0.017460                        0.045505
# 17                                    NaN                             NaN
# 18                               0.371807                        0.364951
# 19                                    NaN                        0.863437
# 20                                    NaN                        0.935093
# 21                                    NaN                        0.581718
# 22                                    NaN                        0.818151
# 23                                    NaN                        0.403633
# 24                                    NaN                        0.646161
# 25                               0.632802                        0.635853
# 26                                    NaN                        0.336346
# 27                                    NaN                        0.469614
# 28                                    NaN                        0.277509
# 29                                    NaN                        0.357988
# 30                                    NaN                        0.219233
# 31                                    NaN                        0.325122
# 32                               0.623040                        0.623606
# 33                               0.612275                        0.612365
# 34                               0.616709                        0.611470
# 35                                    NaN                        0.800587
# 36                                    NaN                        0.882627
# 37                                    NaN                        0.634097
# 38                                    NaN                        0.748909
# 39                                    NaN                        0.482641
# 40                                    NaN                        0.615269
# 41                               0.628659                        0.619454
# 42                                    NaN                        0.418337
# 43                                    NaN                        0.498677
# 44                                    NaN                        0.351388
# 45                                    NaN                        0.438238
# 46                                    NaN                        0.315843
# 47                                    NaN                        0.391594
# 48                               0.626599                        0.616584
# 49                               0.632278                        0.631753
# 50                               0.637853                        0.629945
# 51                               0.638363                        0.632871
#
# params_file  impl_GANET/large.properties  impl_GANET/large_high_r.properties  \
# 0                                    NaN                                 NaN
# 1                               0.930813                                 NaN
# 2                               0.000000                            0.040699
# 3                               0.000000                            0.032533
# 4                               0.000000                            0.026896
# 5                               0.000000                            0.016928
# 6                               0.000000                            0.012643
# 7                               0.000000                            0.013813
# 8                               1.000000                            1.000000
# 9                               1.000000                            1.000000
# 10                              1.000000                            1.000000
# 11                              0.923493                            1.000000
# 12                              0.000000                            0.949944
# 13                              0.000000                            0.231254
# 14                              0.000000                            0.133016
# 15                              0.000000                            0.059405
# 16                              0.000000                            0.037950
# 17                              0.636925                                 NaN
# 18                              0.420213                            0.417196
# 19                              0.980016                            0.979171
# 20                              0.995555                            0.994960
# 21                              0.918391                            0.892221
# 22                              0.990135                            0.987510
# 23                              0.732766                            0.685034
# 24                              0.944315                            0.935402
# 25                              0.943294                            0.925418
# 26                              0.218297                            0.540059
# 27                              0.796977                            0.767408
# 28                              0.105758                            0.433651
# 29                              0.164837                            0.578779
# 30                              0.057365                            0.176115
# 31                              0.108370                            0.519544
# 32                              0.864142                            0.840783
# 33                              0.813753                            0.791851
# 34                              0.782710                            0.769438
# 35                              0.910538                            0.903977
# 36                              0.958788                            0.959262
# 37                              0.792439                            0.761627
# 38                              0.882499                            0.876458
# 39                              0.626695                            0.601012
# 40                              0.775898                            0.756829
# 41                              0.776084                            0.760270
# 42                              0.532026                            0.512683
# 43                              0.647691                            0.625426
# 44                              0.487276                            0.477590
# 45                              0.575687                            0.553894
# 46                              0.450229                            0.452596
# 47                              0.532801                            0.523292
# 48                              0.760683                            0.746966
# 49                              0.756665                            0.739476
# 50                              0.745822                            0.731084
# 51                              0.736904                            0.725461
#
# params_file  impl_GANET/low_cross_high_m.properties
# 0                                               NaN
# 1                                               NaN
# 2                                          0.000000
# 3                                          0.000000
# 4                                          0.000000
# 5                                          0.000000
# 6                                          0.000000
# 7                                          0.000000
# 8                                          0.966106
# 9                                          0.796509
# 10                                         0.585698
# 11                                         0.340099
# 12                                         0.000000
# 13                                         0.000000
# 14                                         0.000000
# 15                                         0.000000
# 16                                         0.000000
# 17                                              NaN
# 18                                         0.355039
# 19                                         0.717836
# 20                                         0.823007
# 21                                         0.464105
# 22                                         0.660465
# 23                                         0.291137
# 24                                         0.511868
# 25                                         0.516822
# 26                                         0.136763
# 27                                         0.261156
# 28                                         0.102360
# 29                                         0.131227
# 30                                         0.082680
# 31                                         0.109004
# 32                                         0.547398
# 33                                         0.555771
# 34                                         0.574925
# 35                                              NaN
# 36                                         0.838640
# 37                                              NaN
# 38                                         0.700349
# 39                                              NaN
# 40                                         0.584279
# 41                                         0.586631
# 42                                              NaN
# 43                                         0.473505
# 44                                         0.338299
# 45                                         0.414045
# 46                                         0.290542
# 47                                         0.362869
# 48                                         0.583552
# 49                                         0.598977
# 50                                         0.599897
# 51                                         0.606826

# %%
with open('ganet.tex','w') as tf:
    tf.write(ganet_valtable.to_latex())

# %%
gacd_valtable = gacd.groupby(['filename','params_file'], sort=False)['nmi'].max().reset_index().pivot('filename', 'params_file', 'nmi').reset_index()
gacd_valtable
# Out:
# params_file                    filename  impl_GACD/default.properties  \
# 0                          dolphins.gml                           NaN
# 1                          football.gml                      0.849917
# 2                  girvan_kout_10_0.gml                      0.112101
# 3                  girvan_kout_11_0.gml                      0.097102
# 4                  girvan_kout_12_0.gml                      0.084187
# 5                  girvan_kout_13_0.gml                      0.068789
# 6                  girvan_kout_14_0.gml                      0.051171
# 7                  girvan_kout_15_0.gml                      0.045338
# 8                   girvan_kout_1_0.gml                      1.000000
# 9                   girvan_kout_2_0.gml                      1.000000
# 10                  girvan_kout_3_0.gml                      1.000000
# 11                  girvan_kout_4_0.gml                      0.974832
# 12                  girvan_kout_5_0.gml                      0.857495
# 13                  girvan_kout_6_0.gml                      0.627994
# 14                  girvan_kout_7_0.gml                      0.464497
# 15                  girvan_kout_8_0.gml                      0.208523
# 16                  girvan_kout_9_0.gml                      0.138650
# 17                           karate.gml                      0.687263
# 18           lfr_10000_mu3_s_size_0.gml                      0.344538
# 19                 lfr_1000_mu1_b_0.gml                      0.820612
# 20                 lfr_1000_mu1_s_0.gml                      0.884997
# 21                 lfr_1000_mu2_b_0.gml                      0.579872
# 22                 lfr_1000_mu2_s_0.gml                      0.740667
# 23                 lfr_1000_mu3_b_0.gml                      0.438944
# 24                 lfr_1000_mu3_s_0.gml                      0.576721
# 25            lfr_1000_mu3_s_size_0.gml                      0.566536
# 26                 lfr_1000_mu4_b_0.gml                      0.347666
# 27                 lfr_1000_mu4_s_0.gml                      0.447399
# 28                 lfr_1000_mu5_b_0.gml                      0.258672
# 29                 lfr_1000_mu5_s_0.gml                      0.351950
# 30                 lfr_1000_mu6_b_0.gml                      0.220989
# 31                 lfr_1000_mu6_s_0.gml                      0.320080
# 32            lfr_2000_mu3_s_size_0.gml                      0.563816
# 33            lfr_3000_mu3_s_size_0.gml                      0.560597
# 34            lfr_4000_mu3_s_size_0.gml                      0.594383
# 35                 lfr_5000_mu1_s_0.gml                      0.843672
# 36                 lfr_5000_mu2_s_0.gml                      0.694285
# 37                 lfr_5000_mu3_s_0.gml                      0.586743
# 38            lfr_5000_mu3_s_size_0.gml                      0.576845
# 39                 lfr_5000_mu4_s_0.gml                      0.493355
# 40                 lfr_5000_mu5_b_0.gml                      0.345738
# 41                 lfr_5000_mu5_s_0.gml                      0.432830
# 42                 lfr_5000_mu6_b_0.gml                      0.296454
# 43                 lfr_5000_mu6_s_0.gml                      0.379515
# 44            lfr_6000_mu3_s_size_0.gml                      0.614720
# 45            lfr_7000_mu3_s_size_0.gml                      0.595149
# 46            lfr_8000_mu3_s_size_0.gml                      0.601671
# 47            lfr_9000_mu3_s_size_0.gml                      0.607417
# 48                         polblogs.gml                      0.334985
#
# params_file  impl_GACD/large.properties  \
# 0                                   NaN
# 1                              0.906000
# 2                              0.097917
# 3                              0.101755
# 4                              0.086894
# 5                              0.048726
# 6                              0.049528
# 7                              0.038991
# 8                              1.000000
# 9                              1.000000
# 10                             1.000000
# 11                             0.974832
# 12                             0.857780
# 13                             0.711194
# 14                             0.568303
# 15                             0.269082
# 16                             0.128651
# 17                             0.687263
# 18                             0.333019
# 19                             0.815051
# 20                             0.869370
# 21                             0.613172
# 22                             0.720521
# 23                             0.447297
# 24                             0.574540
# 25                             0.578782
# 26                             0.331004
# 27                             0.434652
# 28                             0.275366
# 29                             0.399636
# 30                             0.185268
# 31                             0.309400
# 32                             0.585167
# 33                             0.569775
# 34                             0.577697
# 35                             0.847102
# 36                             0.710859
# 37                             0.583373
# 38                             0.590368
# 39                             0.489018
# 40                             0.341076
# 41                             0.424991
# 42                             0.296994
# 43                             0.377877
# 44                             0.589508
# 45                             0.597585
# 46                             0.593479
# 47                             0.598975
# 48                             0.331481
#
# params_file  impl_GACD/low_mut_high_cross.properties
# 0                                                NaN
# 1                                           0.867801
# 2                                           0.159798
# 3                                           0.099882
# 4                                           0.096975
# 5                                           0.070739
# 6                                           0.059236
# 7                                           0.049034
# 8                                           1.000000
# 9                                           1.000000
# 10                                          1.000000
# 11                                          0.974832
# 12                                          0.905740
# 13                                          0.672766
# 14                                          0.472527
# 15                                          0.280174
# 16                                          0.176734
# 17                                          0.687263
# 18                                          0.335753
# 19                                          0.797771
# 20                                          0.870236
# 21                                          0.580732
# 22                                          0.702209
# 23                                          0.432595
# 24                                          0.559754
# 25                                          0.568271
# 26                                          0.320488
# 27                                          0.475701
# 28                                          0.286952
# 29                                          0.391491
# 30                                          0.176202
# 31                                          0.303119
# 32                                          0.582341
# 33                                          0.563544
# 34                                          0.564480
# 35                                          0.832440
# 36                                          0.698517
# 37                                          0.585733
# 38                                          0.573780
# 39                                          0.483826
# 40                                          0.326249
# 41                                          0.417578
# 42                                          0.289675
# 43                                          0.371045
# 44                                          0.587083
# 45                                          0.597150
# 46                                          0.608012
# 47                                          0.603455
# 48                                          0.342715

# %%
with open('gacd.tex','w') as tf:
    tf.write(ganet_valtable.to_latex())

# %%
tbga_valtable = tbga.groupby(['filename','params_file'], sort=False)['nmi'].mean().reset_index().pivot('filename', 'params_file', 'nmi').reset_index()
tbga_valtable
# Out:
# params_file                    filename  impl_TasginGA/default.properties  \
# 0                          dolphins.gml                               NaN
# 1                          football.gml                          0.741184
# 2                  girvan_kout_10_0.gml                          0.058013
# 3                  girvan_kout_11_0.gml                          0.046586
# 4                  girvan_kout_12_0.gml                          0.037238
# 5                  girvan_kout_13_0.gml                          0.034454
# 6                  girvan_kout_14_0.gml                          0.031786
# 7                  girvan_kout_15_0.gml                          0.022816
# 8                   girvan_kout_1_0.gml                          1.000000
# 9                   girvan_kout_2_0.gml                          1.000000
# 10                  girvan_kout_3_0.gml                          0.983983
# 11                  girvan_kout_4_0.gml                          0.942085
# 12                  girvan_kout_5_0.gml                          0.874499
# 13                  girvan_kout_6_0.gml                          0.673606
# 14                  girvan_kout_7_0.gml                          0.408089
# 15                  girvan_kout_8_0.gml                          0.216340
# 16                  girvan_kout_9_0.gml                          0.084964
# 17                           karate.gml                          0.678423
# 18           lfr_10000_mu3_s_size_0.gml                          0.266617
# 19                 lfr_1000_mu1_b_0.gml                          0.944796
# 20                 lfr_1000_mu1_s_0.gml                          0.917641
# 21                 lfr_1000_mu2_b_0.gml                          0.807591
# 22                 lfr_1000_mu2_s_0.gml                          0.804872
# 23                 lfr_1000_mu3_b_0.gml                          0.656177
# 24                 lfr_1000_mu3_s_0.gml                          0.660195
# 25            lfr_1000_mu3_s_size_0.gml                          0.656859
# 26                 lfr_1000_mu4_b_0.gml                          0.331574
# 27                 lfr_1000_mu4_s_0.gml                          0.396012
# 28                 lfr_1000_mu5_b_0.gml                          0.225200
# 29                 lfr_1000_mu5_s_0.gml                          0.288316
# 30                 lfr_1000_mu6_b_0.gml                          0.134398
# 31                 lfr_1000_mu6_s_0.gml                          0.234963
# 32            lfr_2000_mu3_s_size_0.gml                          0.650346
# 33            lfr_3000_mu3_s_size_0.gml                          0.655390
# 34            lfr_4000_mu3_s_size_0.gml                          0.669950
# 35                 lfr_5000_mu1_b_0.gml                          0.897490
# 36                 lfr_5000_mu1_s_0.gml                          0.897496
# 37                 lfr_5000_mu2_b_0.gml                          0.774828
# 38                 lfr_5000_mu2_s_0.gml                          0.784770
# 39                 lfr_5000_mu3_b_0.gml                          0.647095
# 40                 lfr_5000_mu3_s_0.gml                          0.671965
# 41            lfr_5000_mu3_s_size_0.gml                          0.659444
# 42                 lfr_5000_mu4_b_0.gml                          0.438830
# 43                 lfr_5000_mu4_s_0.gml                          0.497231
# 44                 lfr_5000_mu5_b_0.gml                          0.297197
# 45                 lfr_5000_mu5_s_0.gml                          0.378444
# 46                 lfr_5000_mu6_b_0.gml                          0.247211
# 47                 lfr_5000_mu6_s_0.gml                          0.315262
# 48            lfr_6000_mu3_s_size_0.gml                          0.668564
# 49            lfr_7000_mu3_s_size_0.gml                          0.676924
# 50            lfr_8000_mu3_s_size_0.gml                          0.683656
# 51            lfr_9000_mu3_s_size_0.gml                          0.685235
#
# params_file  impl_TasginGA/high_elite.properties  \
# 0                                            NaN
# 1                                       0.715898
# 2                                       0.053976
# 3                                       0.043523
# 4                                       0.039944
# 5                                       0.031440
# 6                                       0.031933
# 7                                       0.030573
# 8                                       1.000000
# 9                                       0.997523
# 10                                      0.949352
# 11                                      0.882696
# 12                                      0.783194
# 13                                      0.555106
# 14                                      0.310959
# 15                                      0.174776
# 16                                      0.085907
# 17                                      0.688485
# 18                                      0.227321
# 19                                      0.923356
# 20                                      0.891162
# 21                                      0.765689
# 22                                      0.761403
# 23                                      0.597478
# 24                                      0.607600
# 25                                      0.610919
# 26                                      0.262427
# 27                                      0.358641
# 28                                      0.168157
# 29                                      0.244587
# 30                                      0.116184
# 31                                      0.192374
# 32                                      0.598863
# 33                                      0.607315
# 34                                      0.610598
# 35                                      0.864147
# 36                                      0.869132
# 37                                      0.728826
# 38                                      0.747121
# 39                                      0.599618
# 40                                      0.625865
# 41                                      0.621375
# 42                                      0.365414
# 43                                      0.435276
# 44                                      0.247465
# 45                                      0.334449
# 46                                      0.197648
# 47                                      0.263287
# 48                                      0.631834
# 49                                      0.633263
# 50                                      0.638224
# 51                                      0.642035
#
# params_file  impl_TasginGA/high_init.properties  \
# 0                                           NaN
# 1                                      0.739433
# 2                                      0.057011
# 3                                      0.036791
# 4                                      0.032293
# 5                                      0.028707
# 6                                      0.026173
# 7                                      0.023768
# 8                                      1.000000
# 9                                      1.000000
# 10                                     0.981731
# 11                                     0.938744
# 12                                     0.886130
# 13                                     0.687552
# 14                                     0.377029
# 15                                     0.207875
# 16                                     0.081083
# 17                                     0.687263
# 18                                     0.232009
# 19                                     0.934695
# 20                                     0.907026
# 21                                     0.799624
# 22                                     0.770115
# 23                                     0.629369
# 24                                     0.629787
# 25                                     0.630760
# 26                                     0.288460
# 27                                     0.386434
# 28                                     0.186291
# 29                                     0.259486
# 30                                     0.108227
# 31                                     0.194399
# 32                                     0.625561
# 33                                     0.618184
# 34                                     0.623122
# 35                                     0.875075
# 36                                     0.868131
# 37                                     0.738134
# 38                                     0.750238
# 39                                     0.615826
# 40                                     0.630319
# 41                                     0.624339
# 42                                     0.382090
# 43                                     0.452875
# 44                                     0.250861
# 45                                     0.333089
# 46                                     0.189130
# 47                                     0.270336
# 48                                     0.633273
# 49                                     0.642858
# 50                                     0.642072
# 51                                     0.647912
#
# params_file  impl_TasginGA/high_mut.properties  impl_TasginGA/large.properties
# 0                                          NaN                             NaN
# 1                                     0.741707                        0.791795
# 2                                     0.062516                        0.038257
# 3                                     0.041119                        0.038737
# 4                                     0.044231                        0.028585
# 5                                     0.035418                        0.018297
# 6                                     0.029513                        0.015523
# 7                                     0.021258                        0.012853
# 8                                     1.000000                        1.000000
# 9                                     1.000000                        1.000000
# 10                                    0.984874                        1.000000
# 11                                    0.938012                        1.000000
# 12                                    0.880621                        1.000000
# 13                                    0.675278                        0.961720
# 14                                    0.416565                        0.775826
# 15                                    0.209499                        0.318571
# 16                                    0.083488                        0.082832
# 17                                    0.688485                        0.687263
# 18                                    0.264135                        0.263370
# 19                                    0.945835                        0.973826
# 20                                    0.914916                        0.943347
# 21                                    0.811761                        0.911146
# 22                                    0.795364                        0.852972
# 23                                    0.647830                        0.797824
# 24                                    0.645352                        0.749043
# 25                                    0.648168                        0.734812
# 26                                    0.325454                        0.417021
# 27                                    0.395512                        0.494253
# 28                                    0.217667                        0.252298
# 29                                    0.288867                        0.339055
# 30                                    0.138578                        0.160547
# 31                                    0.241564                        0.272810
# 32                                    0.653308                        0.705827
# 33                                    0.652423                        0.700778
# 34                                    0.652831                        0.688912
# 35                                    0.899769                        0.906624
# 36                                    0.893212                        0.901649
# 37                                    0.772707                        0.800696
# 38                                    0.785012                        0.800473
# 39                                    0.642259                        0.692395
# 40                                    0.660654                        0.697254
# 41                                    0.669571                        0.696568
# 42                                    0.423005                        0.481651
# 43                                    0.497711                        0.522983
# 44                                    0.303800                        0.305233
# 45                                    0.372747                        0.387913
# 46                                    0.240095                        0.249650
# 47                                    0.313558                        0.322243
# 48                                    0.670897                        0.694840
# 49                                    0.680211                        0.701481
# 50                                    0.683857                        0.697694
# 51                                    0.688298                        0.701682

# %%
with open('tasgin.tex','w') as tf:
    tf.write(tbga_valtable.to_latex())

# %%
plot_data = df[['file', 'true_membership']]
plot_data['true_membership'] = plot_data['true_membership'].apply(lambda s: ' '.join(str(e) for e in s))
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plot_data = plot_data.drop_duplicates()

# %%
for x, y in zip(plot_data['file'], plot_data['true_membership']):
    if "lfr" not in x and "dolphins" not in x:
        print(x)
        y = [int(i) for i in y.split(" ") if i != '']
        print(len(y))
        g = ig.Graph.Read(x, format='gml')
        coms = ig.VertexClustering(g, membership=y)
        plt = ig.plot(coms, mark_groups = True, vertex_size=2)
        plt.save(x.split('/')[-1]+".png")
        print("saved")
# Out:
# D:/alien-pineapple/benchmark_gen/gml_files/real_networks/football.gml
# 115
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/real_networks/karate.gml
# 34
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_10_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_11_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_12_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_13_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_14_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_15_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_1_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_2_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_3_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_4_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_5_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_6_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_7_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_8_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/benchmarks/gn_kout/girvan_kout_9_0.gml
# 128
# saved
# D:/alien-pineapple/benchmark_gen/gml_files/real_networks/polblogs.gml
# 1490
# saved

# %%
def plot_graph(filename):
    g = ig.Graph.Read(filename, format='gml')
    membership = getTrueComs(filename)
    coms = ig.VertexClustering(g, membership=membership)
    plt = ig.plot(coms, mark_groups = True, vertex_size=0, bbox=(20000,20000))
    imagename = filename.split("\\")[-1]
    imagename = imagename.split(".")[0]
    print(imagename)
    plt.save(imagename+".png")

# %%
plot_graph('D:\\alien-pineapple\\benchmark_gen\\gml_files\\benchmarks\\lfr2\\n1000b\\lfr_1000_mu3_b_0.gml')
# Out:
# lfr_1000_mu3_b_0

# %%
plot_graph('D:\\alien-pineapple\\benchmark_gen\\gml_files\\benchmarks\\lfr2\\n1000b\\lfr_1000_mu4_b_0.gml')
# Out:
# lfr_1000_mu4_b_0

# %%
plot_graph('D:\\alien-pineapple\\benchmark_gen\\gml_files\\benchmarks\\lfr2\\n1000b\\lfr_1000_mu5_b_0.gml')
# Out:
# lfr_1000_mu5_b_0

# %%
plot_graph('D:\\alien-pineapple\\benchmark_gen\\gml_files\\benchmarks\\lfr2\\n1000b\\lfr_1000_mu6_b_0.gml')
# Out:
# lfr_1000_mu6_b_0

# %%
def convergence_curve(dataframe):
    files = dataframe['file'].unique()
    params = dataframe['params_file'].unique()

    for file in files:
        for param in params:
            batch = dataframe[(dataframe['file']==file) & (dataframe['params_file']==param)]
            best_mean = np.array(np.mean(np.matrix(batch['best_scores'].tolist()), axis=0)).flatten()
            avg_mean = np.array(np.mean(np.matrix(batch['average_scores'].tolist()), axis=0)).flatten()
            x=[i for i in range(len(best_mean))] 
            y=best_mean.tolist()
            plt.plot(x, y, label="best")
            plt.xlabel('Generation')
            plt.ylabel('Modularity')
            plt.title('Convergence of GANETff')
            plt.plot(avg_mean.tolist(), label="avg")
            plt.legend()
            plt.show()

# %%
convergence_curve(ganet)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-188-97cfcd31c695> in <module>()
# ----> 1 convergence_curve(ganet)
#
# <ipython-input-187-1b691f42bd3c> in convergence_curve(dataframe)
#      10             x=[i for i in range(len(best_mean))]
#      11             y=best_mean.tolist()
# ---> 12             plt.plot(x, y, label="best")
#      13             plt.xlabel('Generation')
#      14             plt.ylabel('Modularity')
#
# AttributeError: 'Plot' object has no attribute 'plot'

# %%
def extract_size(name):
    file = str(name.split('/')[-1])
    size = None
    if 'lfr' in file:
        size = file.split('_')[1]
    elif 'girvan' in file:
        size = 128
    
    return size
    
    
def extract_mu(name):
    file = str(name.split('/')[-1])
    mu = None
    if 'mu' in file:
        mu = file.split('_')[2]
        mu = mu[2:]
    return mu


def extract_kout(name):
    file = str(name.split('/')[-1])
    mu = None
    if 'kout' in file:
        mu = file.split('_')[2]
    return mu


df['short_file'] = df['file'].apply(lambda s: str(s.split('/')[-1]))
df['size'] = df['file'].apply(lambda s: extract_size(s))
df['mu'] = df['file'].apply(lambda s: extract_mu(s))
df['kout'] = df['file'].apply(lambda s: extract_kout(s))

# %%
df.head()

# %%
def params_kruskal(dataframe):
    files = dataframe['file'].unique()
    params = dataframe['params_file'].unique()
    for file in files:
        results = []
        for param in params:
            batch = dataframe[(dataframe['file']==file) & (dataframe['params_file']==param)]
            results.append(batch['nmi'].tolist())
        res = None
        try:
            res = stats.kruskal(*results)
        except(ValueError):
            res = "equal populations"
        print(res, 
              file.split('/')[-1], 
              res.pvalue < res.statistic if type(res) is not str else None)

# %%
params_kruskal(gals)
