# %%
# %matplotlib inline
import os
import igraph as ig
import pandas as pd
from scipy import stats
import numpy as np
import sqlite3
import matplotlib.pyplot as plt

# %% [markdown]
# ## Analysis of Genetic Algorithms for Community Detection in Complex Networks

# %%
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("ClusterResults.db")
df = pd.read_sql_query("SELECT * from ClusterResults where params_file not like '%large%'", con)

# Verify that result of SQL query is stored in the dataframe
con.close()
df.head()
# Out:
#    algo            seed                                               file  \
# 0  gals  13369360549290  D:/alien-pineapple/benchmark_gen/gml_files/ben...
# 1  gals  13369360549290  D:/alien-pineapple/benchmark_gen/gml_files/ben...
# 2  gals  13369360549290  D:/alien-pineapple/benchmark_gen/gml_files/ben...
# 3  gals  13369360549290  D:/alien-pineapple/benchmark_gen/gml_files/ben...
# 4  gals  13369360549290  D:/alien-pineapple/benchmark_gen/gml_files/ben...
#
#                                       average_scores  \
# 0  0.44009612959866123\n0.5461974760784992\n0.605...
# 1  0.44102171729926565\n0.5457098792826734\n0.609...
# 2  0.4402410463825556\n0.5448017280194865\n0.6035...
# 3  0.4390068762765545\n0.545385871564504\n0.60710...
# 4  0.43838356561266134\n0.5446626617100198\n0.605...
#
#                                          best_scores         final_score  \
# 0  0.5421854674251742\n0.6269896726720868\n0.6793...  0.8174163816764717
# 1  0.5605900188715776\n0.6435192651567331\n0.6994...  0.8183975072639841
# 2  0.5558795911697045\n0.6299240468040519\n0.6866...   0.817829138322348
# 3  0.5386790824759569\n0.6246539036437487\n0.6933...  0.8119665565380684
# 4  0.5284876212325604\n0.6271894762815291\n0.7049...  0.8169301644245596
#
#                     params_file  \
# 0  impl_GALS/default.properties
# 1  impl_GALS/default.properties
# 2  impl_GALS/default.properties
# 3  impl_GALS/default.properties
# 4  impl_GALS/default.properties
#
#                                           membership  nmi  rand   vi
# 0  1,2,3,1,2,4,5,6,2,6,7,8,9,10,11,5,12,6,13,14,1...  0.0   0.0  0.0
# 1  1,2,3,1,2,4,5,6,2,6,7,8,9,10,11,5,12,6,13,14,1...  0.0   0.0  0.0
# 2  1,2,3,1,2,4,5,6,2,6,7,8,9,10,11,5,12,6,13,14,1...  0.0   0.0  0.0
# 3  1,2,3,1,2,4,5,6,2,6,7,8,9,10,11,5,12,6,13,14,1...  0.0   0.0  0.0
# 4  1,2,3,1,2,4,5,6,2,6,7,8,9,10,11,5,12,6,13,14,1...  0.0   0.0  0.0

# %%
df['membership'] = df['membership'].apply(lambda s: map(int, s.split(',')))
df['best_scores'] = df['best_scores'].apply(lambda s: map(float, s.split('\n')))
df['average_scores'] = df['average_scores'].apply(lambda s: map(float, s.split('\n')))

# %%
df['filename'] = df['file'].apply(lambda s: os.path.basename(s))

# %%
def getTrueComs(file):
    true_file = file + ".coms"
    if os.path.exists(true_file):
        data = pd.read_csv(true_file, sep='\t', header=None)
        return list(data[1].as_matrix())
    else:
        return []

# %%
df['true_membership'] = df['file'].apply(lambda s: getTrueComs(s))

# %% [markdown]
# ## Comparison Metrics
#
# @article{rand1971,
#   added-at = {2006-03-21T11:09:44.000+0100},
#   author = {Rand, W.M.},
#   biburl = {https://www.bibsonomy.org/bibtex/2fd52548cb4bcd8e83dd27e4b55eff1f3/hotho},
#   interhash = {1afaf0170bc705a9e49b625f67679ee2},
#   intrahash = {fd52548cb4bcd8e83dd27e4b55eff1f3},
#   journal = {Journal of the American Statistical Association },
#   keywords = {cluster clustering criteria evaluation index rand},
#   number = 336,
#   pages = {846-850},
#   timestamp = {2007-09-18T14:44:34.000+0200},
#   title = {Objective criteria for the evaluation of clustering methods},
#   volume = 66,
#   year = 1971
# }

# %%
df['nmi'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="nmi"), axis=1)

df['vi'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="vi"), axis=1)

df['rand'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="rand"), axis=1)

df['adjusted_rand'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="adjusted_rand"), axis=1)

df['split_join'] = df[['membership', 'true_membership']].apply(lambda s: 
                                                        None if s[1] == [] else 
                                                        ig.compare_communities(s[0], s[1], method="split-join"), axis=1)

# %%
def identifyConverge(vals):
    """find the earliest occurance of the maximum value in a list
    """
    best = vals[-1]
    if vals[0] == best:
        return 0
    for i in range(len(vals)):
        if vals[i] == best:
            return i

# %%
df['converge_gen'] = df['best_scores'].apply(identifyConverge)
df['gens'] = df['best_scores'].apply(len)

# %%
def extract_size(name):
    file = str(name.split('/')[-1])
    size = None
    if 'lfr' in file:
        size = file.split('_')[1]
    elif 'girvan' in file:
        size = 128
    
    return size
    
    
def extract_mu(name):
    file = str(name.split('/')[-1])
    mu = None
    if 'mu' in file:
        mu = file.split('_')[2]
        mu = mu[2:]
    return mu


def extract_kout(name):
    file = str(name.split('/')[-1])
    mu = None
    if 'kout' in file:
        mu = file.split('_')[2]
    return mu


df['short_file'] = df['file'].apply(lambda s: str(s.split('/')[-1]))
df['size'] = df['file'].apply(lambda s: extract_size(s))
df['mu'] = df['file'].apply(lambda s: extract_mu(s))
df['kout'] = df['file'].apply(lambda s: extract_kout(s))

# %%
gals = df.loc[lambda dd: dd['algo'] == 'gals']
gacd = df.loc[lambda dd: dd['algo'] == 'gacd']
tbga = df.loc[lambda dd: dd['algo'] == 'tasgin']
ganet = df.loc[lambda dd: dd['algo'] == 'ganet']

# %%
def highlight_max(s):
    """
    highlight the maximum in a Series yellow.
    """
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
gals_valtable = gals.groupby(['filename','params_file'], sort=False)['nmi'].mean().reset_index().pivot('filename', 'params_file', 'nmi')
gals_valtable.style.apply(highlight_max, axis=1)
# Out:
# <style  type="text/css" >
#     #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow2_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow3_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow4_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow5_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow6_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow7_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow8_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow9_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow10_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow11_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow12_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow13_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow14_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow15_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow16_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow18_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow19_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow20_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow21_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow22_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow23_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow24_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow25_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow26_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow27_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow28_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow29_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow30_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow31_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow32_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow33_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow34_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow35_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow36_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow37_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow38_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow39_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow40_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow41_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow42_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow43_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow44_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow45_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow46_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow47_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow48_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow49_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow50_col0 {
#             background-color:  yellow;
#         }    #T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow51_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545e" >
# <thead>    <tr>
#         <th class="index_name level0" >params_file</th>
#         <th class="col_heading level0 col0" >impl_GALS/default.properties</th>
#     </tr>    <tr>
#         <th class="index_name level0" >filename</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545elevel0_row0" class="row_heading level0 row0" >dolphins.gml</th>
#         <td id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow0_col0" class="data row0 col0" >nan</td>
#     </tr>    <tr>
#         <th id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545elevel0_row1" class="row_heading level0 row1" >football.gml</th>
#         <td id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow1_col0" class="data row1 col0" >nan</td>
#     </tr>    <tr>
#         <th id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545elevel0_row2" class="row_heading level0 row2" >girvan_kout_10_0.gml</th>
#         <td id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow2_col0" class="data row2 col0" >0.0886493</td>
#     </tr>    <tr>
#         <th id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545elevel0_row3" class="row_heading level0 row3" >girvan_kout_11_0.gml</th>
#         <td id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow3_col0" class="data row3 col0" >0.0661671</td>
#     </tr>    <tr>
#         <th id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545elevel0_row4" class="row_heading level0 row4" >girvan_kout_12_0.gml</th>
#         <td id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow4_col0" class="data row4 col0" >0.0482544</td>
#     </tr>    <tr>
#         <th id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545elevel0_row5" class="row_heading level0 row5" >girvan_kout_13_0.gml</th>
#         <td id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow5_col0" class="data row5 col0" >0.0371656</td>
#     </tr>    <tr>
#         <th id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545elevel0_row6" class="row_heading level0 row6" >girvan_kout_14_0.gml</th>
#         <td id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow6_col0" class="data row6 col0" >0.0431408</td>
#     </tr>    <tr>
#         <th id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545elevel0_row7" class="row_heading level0 row7" >girvan_kout_15_0.gml</th>
#         <td id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow7_col0" class="data row7 col0" >0.0284754</td>
#     </tr>    <tr>
#         <th id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545elevel0_row8" class="row_heading level0 row8" >girvan_kout_1_0.gml</th>
#         <td id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow8_col0" class="data row8 col0" >1</td>
#     </tr>    <tr>
#         <th id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545elevel0_row9" class="row_heading level0 row9" >girvan_kout_2_0.gml</th>
#         <td id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545erow9_col0" class="data row9 col0" >1</td>
#     </tr>    <tr>
#         <th id="T_9baa5a30_21b5_11e8_9f9a_1c1b0d03545elevel0

# %%
with open('gals.tex','w') as tf:
    tf.write(gals_valtable.to_latex())

# %%
ganet_valtable = ganet.groupby(['filename','params_file'], sort=False)['nmi'].mean().reset_index().pivot('filename', 'params_file', 'nmi')

ganet_valtable.style.apply(highlight_max, axis=1)
# Out:
# <style  type="text/css" >
#     #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow2_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow3_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow4_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow5_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow6_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow7_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow8_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow8_col2 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow8_col3 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow8_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow9_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow9_col2 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow9_col3 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow9_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow10_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow10_col3 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow10_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow11_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow12_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow13_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow14_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow15_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow16_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow18_col3 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow19_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow20_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow21_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow22_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow23_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow24_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow25_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow26_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow27_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow28_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow29_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow30_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow31_col4 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow32_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow33_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow34_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow35_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow36_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow37_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow38_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow39_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow40_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow41_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow42_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow43_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow44_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow45_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow46_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow47_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow48_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow49_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow50_col1 {
#             background-color:  yellow;
#         }    #T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow51_col1 {
#             background-color:  yellow;
#         }</style>
# <table id="T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545e" >
# <thead>    <tr>
#         <th class="index_name level0" >params_file</th>
#         <th class="col_heading level0 col0" >impl_GANET/balanced_c_m.properties</th>
#         <th class="col_heading level0 col1" >impl_GANET/default.properties</th>
#         <th class="col_heading level0 col2" >impl_GANET/high_elite.properties</th>
#         <th class="col_heading level0 col3" >impl_GANET/high_r.properties</th>
#         <th class="col_heading level0 col4" >impl_GANET/higher_r.properties</th>
#         <th class="col_heading level0 col5" >impl_GANET/low_cross_high_m.properties</th>
#     </tr>    <tr>
#         <th class="index_name level0" >filename</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545elevel0_row0" class="row_heading level0 row0" >dolphins.gml</th>
#         <td id="T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow0_col0" class="data row0 col0" >nan</td>
#         <td id="T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow0_col1" class="data row0 col1" >nan</td>
#         <td id="T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow0_col2" class="data row0 col2" >nan</td>
#         <td id="T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow0_col3" class="data row0 col3" >nan</td>
#         <td id="T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow0_col4" class="data row0 col4" >nan</td>
#         <td id="T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow0_col5" class="data row0 col5" >nan</td>
#     </tr>    <tr>
#         <th id="T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545elevel0_row1" class="row_heading level0 row1" >football.gml</th>
#         <td id="T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow1_col0" class="data row1 col0" >nan</td>
#         <td id="T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545erow1_col1" class="data row1 col1" >nan</td>
#         <td id="T_9bb3f721_21b5_11e8_9cf5_1c1b0d03545ero

# %%
with open('ganet.tex','w') as tf:
    tf.write(ganet_valtable.to_latex())

# %%
gacd_valtable = gacd.groupby(['filename','params_file'], sort=False)['nmi'].max().reset_index().pivot('filename', 'params_file', 'nmi')
gacd_valtable.style.apply(highlight_max, axis=1)
# Out:
# <style  type="text/css" >
#     #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow2_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow3_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow4_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow5_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow6_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow7_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow8_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow8_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow9_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow9_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow10_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow10_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow11_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow11_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow12_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow13_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow14_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow15_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow16_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow18_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow19_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow20_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow21_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow22_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow23_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow24_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow25_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow26_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow27_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow28_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow29_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow30_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow31_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow32_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow33_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow34_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow35_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow36_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow37_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow38_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow39_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow40_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow41_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow42_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow43_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow44_col0 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow45_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow46_col1 {
#             background-color:  yellow;
#         }    #T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow47_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545e" >
# <thead>    <tr>
#         <th class="index_name level0" >params_file</th>
#         <th class="col_heading level0 col0" >impl_GACD/default.properties</th>
#         <th class="col_heading level0 col1" >impl_GACD/low_mut_high_cross.properties</th>
#     </tr>    <tr>
#         <th class="index_name level0" >filename</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545elevel0_row0" class="row_heading level0 row0" >dolphins.gml</th>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow0_col0" class="data row0 col0" >nan</td>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow0_col1" class="data row0 col1" >nan</td>
#     </tr>    <tr>
#         <th id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545elevel0_row1" class="row_heading level0 row1" >football.gml</th>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow1_col0" class="data row1 col0" >nan</td>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow1_col1" class="data row1 col1" >nan</td>
#     </tr>    <tr>
#         <th id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545elevel0_row2" class="row_heading level0 row2" >girvan_kout_10_0.gml</th>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow2_col0" class="data row2 col0" >0.112101</td>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow2_col1" class="data row2 col1" >0.159798</td>
#     </tr>    <tr>
#         <th id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545elevel0_row3" class="row_heading level0 row3" >girvan_kout_11_0.gml</th>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow3_col0" class="data row3 col0" >0.0971016</td>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow3_col1" class="data row3 col1" >0.0998821</td>
#     </tr>    <tr>
#         <th id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545elevel0_row4" class="row_heading level0 row4" >girvan_kout_12_0.gml</th>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow4_col0" class="data row4 col0" >0.0841867</td>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow4_col1" class="data row4 col1" >0.0969749</td>
#     </tr>    <tr>
#         <th id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545elevel0_row5" class="row_heading level0 row5" >girvan_kout_13_0.gml</th>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow5_col0" class="data row5 col0" >0.0687894</td>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow5_col1" class="data row5 col1" >0.0707389</td>
#     </tr>    <tr>
#         <th id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545elevel0_row6" class="row_heading level0 row6" >girvan_kout_14_0.gml</th>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow6_col0" class="data row6 col0" >0.0511708</td>
#         <td id="T_9bbb9840_21b5_11e8_9c99_1c1b0d03545erow6_col1" class="dat

# %%
with open('gacd.tex','w') as tf:
    tf.write(ganet_valtable.to_latex())

# %%
tbga_valtable = tbga.groupby(['filename','params_file'], sort=False)['nmi'].mean().reset_index().pivot('filename', 'params_file', 'nmi')
tbga_valtable.style.apply(highlight_max, axis=1)
# Out:
# <style  type="text/css" >
#     #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow2_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow3_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow4_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow5_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow6_col1 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow7_col1 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow8_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow8_col1 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow8_col2 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow8_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow9_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow9_col2 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow9_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow10_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow11_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow12_col2 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow13_col2 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow14_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow15_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow16_col1 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow18_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow19_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow20_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow21_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow22_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow23_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow24_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow25_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow26_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow27_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow28_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow29_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow30_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow31_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow32_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow33_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow34_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow35_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow36_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow37_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow38_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow39_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow40_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow41_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow42_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow43_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow44_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow45_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow46_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow47_col0 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow48_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow49_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow50_col3 {
#             background-color:  yellow;
#         }    #T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow51_col3 {
#             background-color:  yellow;
#         }</style>
# <table id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545e" >
# <thead>    <tr>
#         <th class="index_name level0" >params_file</th>
#         <th class="col_heading level0 col0" >impl_TasginGA/default.properties</th>
#         <th class="col_heading level0 col1" >impl_TasginGA/high_elite.properties</th>
#         <th class="col_heading level0 col2" >impl_TasginGA/high_init.properties</th>
#         <th class="col_heading level0 col3" >impl_TasginGA/high_mut.properties</th>
#     </tr>    <tr>
#         <th class="index_name level0" >filename</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545elevel0_row0" class="row_heading level0 row0" >dolphins.gml</th>
#         <td id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow0_col0" class="data row0 col0" >nan</td>
#         <td id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow0_col1" class="data row0 col1" >nan</td>
#         <td id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow0_col2" class="data row0 col2" >nan</td>
#         <td id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow0_col3" class="data row0 col3" >nan</td>
#     </tr>    <tr>
#         <th id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545elevel0_row1" class="row_heading level0 row1" >football.gml</th>
#         <td id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow1_col0" class="data row1 col0" >nan</td>
#         <td id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow1_col1" class="data row1 col1" >nan</td>
#         <td id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow1_col2" class="data row1 col2" >nan</td>
#         <td id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow1_col3" class="data row1 col3" >nan</td>
#     </tr>    <tr>
#         <th id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545elevel0_row2" class="row_heading level0 row2" >girvan_kout_10_0.gml</th>
#         <td id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow2_col0" class="data row2 col0" >0.0580131</td>
#         <td id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow2_col1" class="data row2 col1" >0.0539764</td>
#         <td id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow2_col2" class="data row2 col2" >0.0570108</td>
#         <td id="T_9bc3fcb0_21b5_11e8_ba10_1c1b0d03545erow2_col3" class="data row2 col3" >0.0625157</td>
#     </tr>    <tr>
#         <th

# %%
with open('tasgin.tex','w') as tf:
    tf.write(tbga_valtable.to_latex())

# %%
plot_data = df[['file', 'true_membership']]
plot_data['true_membership'] = plot_data['true_membership'].apply(lambda s: ' '.join(str(e) for e in s))
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plot_data = plot_data.drop_duplicates()

# %%
for x, y in zip(plot_data['file'], plot_data['true_membership']):
    if "lfr" not in x and "dolphins" not in x:
        print(x)
        y = [int(i) for i in y.split(" ") if i != '']
        print(len(y))
        g = ig.Graph.Read(x, format='gml')
        coms = ig.VertexClustering(g, membership=y)
        plt = ig.plot(coms, mark_groups = True, vertex_size=2)
        plt.save(x.split('/')[-1]+".png")
        print("saved")
# Out:
# D:/alien-pineapple/benchmark_gen/gml_files/real_networks/football.gml
# 0
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-24-6c2343da85c1> in <module>()
#       4         y = [int(i) for i in y.split(" ") if i != '']
#       5         print(len(y))
# ----> 6         g = ig.Graph.Read(x, format='gml')
#       7         coms = ig.VertexClustering(g, membership=y)
#       8         plt = ig.plot(coms, mark_groups = True, vertex_size=2)
#
# C:\ProgramData\Anaconda2\lib\site-packages\igraph\__init__.pyc in Read(klass, f, format, *args, **kwds)
#    2221             raise IOError("no reader method for file format: %s" % str(format))
#    2222         reader = getattr(klass, reader)
# -> 2223         return reader(f, *args, **kwds)
#    2224     Load = Read
#    2225
#
# IOError: [Errno 2] No such file or directory: 'D:/alien-pineapple/benchmark_gen/gml_files/real_networks/football.gml'

# %%
def plot_graph(filename):
    g = ig.Graph.Read(filename, format='gml')
    membership = getTrueComs(filename)
    coms = ig.VertexClustering(g, membership=membership)
    plt = ig.plot(coms, mark_groups = True, vertex_size=0, bbox=(20000,20000))
    imagename = filename.split("\\")[-1]
    imagename = imagename.split(".")[0]
    print(imagename)
    plt.save(imagename+".png")

# %%
plot_graph('D:\\alien-pineapple\\benchmark_gen\\gml_files\\benchmarks\\lfr2\\n1000b\\lfr_1000_mu3_b_0.gml')

# %%
plot_graph('D:\\alien-pineapple\\benchmark_gen\\gml_files\\benchmarks\\lfr2\\n1000b\\lfr_1000_mu4_b_0.gml')

# %%
plot_graph('D:\\alien-pineapple\\benchmark_gen\\gml_files\\benchmarks\\lfr2\\n1000b\\lfr_1000_mu5_b_0.gml')

# %%
plot_graph('D:\\alien-pineapple\\benchmark_gen\\gml_files\\benchmarks\\lfr2\\n1000b\\lfr_1000_mu6_b_0.gml')

# %%
def convergence_curve(dataframe):
    files = dataframe['file'].unique()
    params = dataframe['params_file'].unique()

    for file in files:
        for param in params:
            batch = dataframe[(dataframe['file']==file) & (dataframe['params_file']==param)]
            best_mean = np.array(np.mean(np.matrix(batch['best_scores'].tolist()), axis=0)).flatten()
            avg_mean = np.array(np.mean(np.matrix(batch['average_scores'].tolist()), axis=0)).flatten()
            x=[i for i in range(len(best_mean))] 
            y=best_mean.tolist()
            plt.plot(x, y, label="best")
            plt.xlabel('Generation')
            plt.ylabel('Modularity')
            plt.title('Convergence of GANETff')
            plt.plot(avg_mean.tolist(), label="avg")
            plt.legend()
            plt.show()

# %%
convergence_curve(ganet)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-188-97cfcd31c695> in <module>()
# ----> 1 convergence_curve(ganet)
#
# <ipython-input-187-1b691f42bd3c> in convergence_curve(dataframe)
#      10             x=[i for i in range(len(best_mean))]
#      11             y=best_mean.tolist()
# ---> 12             plt.plot(x, y, label="best")
#      13             plt.xlabel('Generation')
#      14             plt.ylabel('Modularity')
#
# AttributeError: 'Plot' object has no attribute 'plot'

# %%
def extract_size(name):
    file = str(name.split('/')[-1])
    size = None
    if 'lfr' in file:
        size = file.split('_')[1]
    elif 'girvan' in file:
        size = 128
    
    return size
    
    
def extract_mu(name):
    file = str(name.split('/')[-1])
    mu = None
    if 'mu' in file:
        mu = file.split('_')[2]
        mu = mu[2:]
    return mu


def extract_kout(name):
    file = str(name.split('/')[-1])
    mu = None
    if 'kout' in file:
        mu = file.split('_')[2]
    return mu


df['short_file'] = df['file'].apply(lambda s: str(s.split('/')[-1]))
df['size'] = df['file'].apply(lambda s: extract_size(s))
df['mu'] = df['file'].apply(lambda s: extract_mu(s))
df['kout'] = df['file'].apply(lambda s: extract_kout(s))

# %%
def params_kruskal(dataframe):
    files = dataframe['file'].unique()
    params = dataframe['params_file'].unique()
    for file in files:
        results = []
        for param in params:
            batch = dataframe[(dataframe['file']==file) & (dataframe['params_file']==param)]
            results.append(batch['nmi'].tolist())
        res = None
        try:
            res = stats.kruskal(*results)
        except(ValueError):
            res = "equal populations"
        print(res, 
              file.split('/')[-1], 
              res.pvalue < res.statistic if type(res) is not str else None)

# %%
params_kruskal(gals)
# Out:
# ('equal populations', u'lfr_1000_mu1_s_0.gml', None)
# ('equal populations', u'lfr_1000_mu2_s_0.gml', None)
# ('equal populations', u'lfr_1000_mu3_s_0.gml', None)
# ('equal populations', u'lfr_1000_mu4_s_0.gml', None)
# ('equal populations', u'lfr_1000_mu5_s_0.gml', None)
# ('equal populations', u'lfr_1000_mu6_s_0.gml', None)
# ('equal populations', u'lfr_1000_mu1_b_0.gml', None)
# ('equal populations', u'lfr_1000_mu2_b_0.gml', None)
# ('equal populations', u'lfr_1000_mu3_b_0.gml', None)
# ('equal populations', u'lfr_1000_mu4_b_0.gml', None)
# ('equal populations', u'lfr_1000_mu5_b_0.gml', None)
# ('equal populations', u'lfr_1000_mu6_b_0.gml', None)
# ('equal populations', u'lfr_5000_mu1_s_0.gml', None)
# ('equal populations', u'lfr_5000_mu2_s_0.gml', None)
# ('equal populations', u'lfr_5000_mu3_s_0.gml', None)
# ('equal populations', u'lfr_5000_mu4_s_0.gml', None)
# ('equal populations', u'lfr_5000_mu5_s_0.gml', None)
# ('equal populations', u'lfr_5000_mu6_s_0.gml', None)
# ('equal populations', u'lfr_5000_mu1_b_0.gml', None)
# ('equal populations', u'lfr_5000_mu2_b_0.gml', None)
# ('equal populations', u'lfr_5000_mu3_b_0.gml', None)
# ('equal populations', u'lfr_5000_mu4_b_0.gml', None)
# ('equal populations', u'lfr_5000_mu5_b_0.gml', None)
# ('equal populations', u'lfr_5000_mu6_b_0.gml', None)
# ('equal populations', u'lfr_10000_mu3_s_size_0.gml', None)
# ('equal populations', u'lfr_1000_mu3_s_size_0.gml', None)
# ('equal populations', u'lfr_2000_mu3_s_size_0.gml', None)
# ('equal populations', u'lfr_3000_mu3_s_size_0.gml', None)
# ('equal populations', u'lfr_4000_mu3_s_size_0.gml', None)
# ('equal populations', u'lfr_5000_mu3_s_size_0.gml', None)
# ('equal populations', u'lfr_6000_mu3_s_size_0.gml', None)
# ('equal populations', u'lfr_7000_mu3_s_size_0.gml', None)
# ('equal populations', u'lfr_8000_mu3_s_size_0.gml', None)
# ('equal populations', u'lfr_9000_mu3_s_size_0.gml', None)
# ('equal populations', u'girvan_kout_10_0.gml', None)
# ('equal populations', u'girvan_kout_11_0.gml', None)
# ('equal populations', u'girvan_kout_12_0.gml', None)
# ('equal populations', u'girvan_kout_13_0.gml', None)
# ('equal populations', u'girvan_kout_14_0.gml', None)
# ('equal populations', u'girvan_kout_15_0.gml', None)
# ('equal populations', u'girvan_kout_1_0.gml', None)
# ('equal populations', u'girvan_kout_2_0.gml', None)
# ('equal populations', u'girvan_kout_3_0.gml', None)
# ('equal populations', u'girvan_kout_4_0.gml', None)
# ('equal populations', u'girvan_kout_5_0.gml', None)
# ('equal populations', u'girvan_kout_6_0.gml', None)
# ('equal populations', u'girvan_kout_7_0.gml', None)
# ('equal populations', u'girvan_kout_8_0.gml', None)
# ('equal populations', u'girvan_kout_9_0.gml', None)
# ('equal populations', u'dolphins.gml', None)
# ('equal populations', u'football.gml', None)
# ('equal populations', u'karate.gml', None)
# ('equal populations', u'polblogs.gml', None)
